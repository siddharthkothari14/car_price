# %%
import numpy as np

# %%
import pandas as pd

# %%
car = pd.read_csv('quikr_car.csv')

# %%
car.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car['year'].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
## cleaning the data

# %%
backup = car.copy()

# %% [raw]
# ##cleaning all the faults in year column
# #make it ino int type data
# #remove non numeric values

# %%
car = car[car['year'].str.isnumeric()]

# %%
car['year'] = car['year'].astype(int)

# %% [raw]
# ## year cleaing complete

# %%
## cleaning price
#remove ask for price
#remove ',' in the data
# make it int type data

# %%
car = car[car['Price']!='Ask For Price']

# %%
car['Price'] = car['Price'].str.replace(',','').astype(int)

# %%
car['kms_driven']=car['kms_driven'].str.split(' ').str.get(0).str.replace(',','')

# %%
car=car[car['kms_driven'].str.isnumeric()]

# %%
car['kms_driven'] = car['kms_driven'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        817 non-null    object
#  1   company     817 non-null    object
#  2   year        817 non-null    int64
#  3   Price       817 non-null    int64
#  4   kms_driven  817 non-null    int64
#  5   fuel_type   816 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 44.7+ KB

# %%
## cleaning fuel type nan

# %%
car=car[~car['fuel_type'].isna()]

# %%
car['name'] = car['name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
car['name']
# Out:
# 0         Hyundai Santro Xing
# 1         Mahindra Jeep CL550
# 3           Hyundai Grand i10
# 4      Ford EcoSport Titanium
# 6                   Ford Figo
#                 ...
# 883        Maruti Suzuki Ritz
# 885            Tata Indica V2
# 886      Toyota Corolla Altis
# 888              Tata Zest XM
# 889        Mahindra Quanto C8
# Name: name, Length: 816, dtype: object

# %%
car=car.reset_index(drop=True)

# %%
car=car[car['Price']<6e6].reset_index(drop=True)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815 entries, 0 to 814
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        815 non-null    object
#  1   company     815 non-null    object
#  2   year        815 non-null    int64
#  3   Price       815 non-null    int64
#  4   kms_driven  815 non-null    int64
#  5   fuel_type   815 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 38.3+ KB

# %%
car.to_csv('clean data for cars.csv')

# %%
## making the mode

# %%
X=car.drop(columns='Price')

# %%
y=car['Price']

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\siddh\appdata\local\programs\python\python312\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\siddh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\siddh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\siddh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\siddh\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
from sklearn.metrics import r2_score

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),
                                    remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
#                                                                             array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['name', 'company',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7728414353893275

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
scores[np.argmax(scores)]
# Out:
# 0.8991157554877304

# %%
pipe.predict(pd.DataFrame(columns=X_test.columns,data=np.array(['Maruti Suzuki Swift','Maruti',2019,100,'Petrol']).reshape(1,5)))
# Out:
# array([430301.37134528])

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.8991157554877304

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame(columns=['name','company','year','kms_driven','fuel_type'],data=np.array(['Maruti Suzuki Swift','Maruti',2019,100,'Petrol']).reshape(1,5)))
# Out:
# array([456670.3272301])

# %%
pipe.steps[0][1].transformers[0][1].categories[0]
# Out:
# array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#        'Chevrolet Beat LS', 'Chevrolet Beat LT', 'Chevrolet Beat PS',
#        'Chevrolet Cruze LTZ', 'Chevrolet Enjoy', 'Chevrolet Enjoy 1.4',
#        'Chevrolet Sail 1.2', 'Chevrolet Sail UVA', 'Chevrolet Spark',
#        'Chevrolet Spark 1.0', 'Chevrolet Spark LS', 'Chevrolet Spark LT',
#        'Chevrolet Tavera LS', 'Chevrolet Tavera Neo', 'Datsun GO T',
#        'Datsun Go Plus', 'Datsun Redi GO', 'Fiat Linea Emotion',
#        'Fiat Petra ELX', 'Fiat Punto Emotion', 'Force Motors Force',
#        'Force Motors One', 'Ford EcoSport', 'Ford EcoSport Ambiente',
#        'Ford EcoSport Titanium', 'Ford EcoSport Trend',
#        'Ford Endeavor 4x4', 'Ford Fiesta', 'Ford Fiesta SXi', 'Ford Figo',
#        'Ford Figo Diesel', 'Ford Figo Duratorq', 'Ford Figo Petrol',
#        'Ford Fusion 1.4', 'Ford Ikon 1.3', 'Ford Ikon 1.6',
#        'Hindustan Motors Ambassador', 'Honda Accord', 'Honda Amaze',
#        'Honda Amaze 1.2', 'Honda Amaze 1.5', 'Honda Brio', 'Honda Brio V',
#        'Honda Brio VX', 'Honda City', 'Honda City 1.5', 'Honda City SV',
#        'Honda City VX', 'Honda City ZX', 'Honda Jazz S', 'Honda Jazz VX',
#        'Honda Mobilio', 'Honda Mobilio S', 'Honda WR V', 'Hyundai Accent',
#        'Hyundai Accent Executive', 'Hyundai Accent GLE',
#        'Hyundai Accent GLX', 'Hyundai Creta', 'Hyundai Creta 1.6',
#        'Hyundai Elantra 1.8', 'Hyundai Elantra SX', 'Hyundai Elite i20',
#        'Hyundai Eon', 'Hyundai Eon D', 'Hyundai Eon Era',
#        'Hyundai Eon Magna', 'Hyundai Eon Sportz', 'Hyundai Fluidic Verna',
#        'Hyundai Getz', 'Hyundai Getz GLE', 'Hyundai Getz Prime',
#        'Hyundai Grand i10', 'Hyundai Santro', 'Hyundai Santro AE',
#        'Hyundai Santro Xing', 'Hyundai Sonata Transform', 'Hyundai Verna',
#        'Hyundai Verna 1.4', 'Hyundai Verna 1.6', 'Hyundai Verna Fluidic',
#        'Hyundai Verna Transform', 'Hyundai Verna VGT',
#        'Hyundai Xcent Base', 'Hyundai Xcent SX', 'Hyundai i10',
#        'Hyundai i10 Era', 'Hyundai i10 Magna', 'Hyundai i10 Sportz',
#        'Hyundai i20', 'Hyundai i20 Active', 'Hyundai i20 Asta',
#        'Hyundai i20 Magna', 'Hyundai i20 Select', 'Hyundai i20 Sportz',
#        'Jaguar XE XE', 'Jaguar XF 2.2', 'Jeep Wrangler Unlimited',
#        'Land Rover Freelander', 'Mahindra Bolero DI',
#        'Mahindra Bolero Power', 'Mahindra Bolero SLE',
#        'Mahindra Jeep CL550', 'Mahindra Jeep MM', 'Mahindra KUV100',
#        'Mahindra KUV100 K8', 'Mahindra Logan', 'Mahindra Logan Diesel',
#        'Mahindra Quanto C4', 'Mahindra Quanto C8', 'Mahindra Scorpio',
#        'Mahindra Scorpio 2.6', 'Mahindra Scorpio LX',
#        'Mahindra Scorpio S10', 'Mahindra Scorpio S4',
#        'Mahindra Scorpio SLE', 'Mahindra Scorpio SLX',
#        'Mahindra Scorpio VLX', 'Mahindra Scorpio Vlx',
#        'Mahindra Scorpio W', 'Mahindra TUV300 T4', 'Mahindra TUV300 T8',
#        'Mahindra Thar CRDe', 'Mahindra XUV500', 'Mahindra XUV500 W10',
#        'Mahindra XUV500 W6', 'Mahindra XUV500 W8', 'Mahindra Xylo D2',
#        'Mahindra Xylo E4', 'Mahindra Xylo E8', 'Maruti Suzuki 800',
#        'Maruti Suzuki A', 'Maruti Suzuki Alto', 'Maruti Suzuki Baleno',
#        'Maruti Suzuki Celerio', 'Maruti Suzuki Ciaz',
#        'Maruti Suzuki Dzire', 'Maruti Suzuki Eeco',
#        'Maruti Suzuki Ertiga', 'Maruti Suzuki Esteem',
#        'Maruti Suzuki Estilo', 'Maruti Suzuki Maruti',
#        'Maruti Suzuki Omni', 'Maruti Suzuki Ritz', 'Maruti Suzuki S',
#        'Maruti Suzuki SX4', 'Maruti Suzuki Stingray',
#        'Maruti Suzuki Swift', 'Maruti Suzuki Versa',
#        'Maruti Suzuki Vitara', 'Maruti Suzuki Wagon', 'Maruti Suzuki Zen',
#        'Mercedes Benz A', 'Mercedes Benz B', 'Mercedes Benz C',
#        'Mercedes Benz GLA', 'Mini Cooper S', 'Mitsubishi Lancer 1.8',
#        'Mitsubishi Pajero Sport', 'Nissan Micra XL', 'Nissan Micra XV',
#        'Nissan Sunny', 'Nissan Sunny XL', 'Nissan Terrano XL',
#        'Nissan X Trail', 'Renault Duster', 'Renault Duster 110',
#        'Renault Duster 110PS', 'Renault Duster 85', 'Renault Duster 85PS',
#        'Renault Duster RxL', 'Renault Kwid', 'Renault Kwid 1.0',
#        'Renault Kwid RXT', 'Renault Lodgy 85', 'Renault Scala RxL',
#        'Skoda Fabia', 'Skoda Fabia 1.2L', 'Skoda Fabia Classic',
#        'Skoda Laura', 'Skoda Octavia Classic', 'Skoda Rapid Elegance',
#        'Skoda Superb 1.8', 'Skoda Yeti Ambition', 'Tata Aria Pleasure',
#        'Tata Bolt XM', 'Tata Indica', 'Tata Indica V2', 'Tata Indica eV2',
#        'Tata Indigo CS', 'Tata Indigo LS', 'Tata Indigo LX',
#        'Tata Indigo Marina', 'Tata Indigo eCS', 'Tata Manza',
#        'Tata Manza Aqua', 'Tata Manza Aura', 'Tata Manza ELAN',
#        'Tata Nano', 'Tata Nano Cx', 'Tata Nano GenX', 'Tata Nano LX',
#        'Tata Nano Lx', 'Tata Sumo Gold', 'Tata Sumo Grande',
#        'Tata Sumo Victa', 'Tata Tiago Revotorq', 'Tata Tiago Revotron',
#        'Tata Tigor Revotron', 'Tata Venture EX', 'Tata Vista Quadrajet',
#        'Tata Zest Quadrajet', 'Tata Zest XE', 'Tata Zest XM',
#        'Toyota Corolla', 'Toyota Corolla Altis', 'Toyota Corolla H2',
#        'Toyota Etios', 'Toyota Etios G', 'Toyota Etios GD',
#        'Toyota Etios Liva', 'Toyota Fortuner', 'Toyota Fortuner 3.0',
#        'Toyota Innova 2.0', 'Toyota Innova 2.5', 'Toyota Qualis',
#        'Volkswagen Jetta Comfortline', 'Volkswagen Jetta Highline',
#        'Volkswagen Passat Diesel', 'Volkswagen Polo',
#        'Volkswagen Polo Comfortline', 'Volkswagen Polo Highline',
#        'Volkswagen Polo Highline1.2L', 'Volkswagen Polo Trendline',
#        'Volkswagen Vento Comfortline', 'Volkswagen Vento Highline',
#        'Volkswagen Vento Konekt', 'Volvo S80 Summum'], dtype=object)

# %%
car['name'].values
# Out:
# array(['Hyundai Santro Xing', 'Mahindra Jeep CL550', 'Hyundai Grand i10',
#        'Ford EcoSport Titanium', 'Ford Figo', 'Hyundai Eon',
#        'Ford EcoSport Ambiente', 'Maruti Suzuki Alto',
#        'Skoda Fabia Classic', 'Maruti Suzuki Stingray',
#        'Hyundai Elite i20', 'Mahindra Scorpio SLE', 'Hyundai Santro Xing',
#        'Mahindra Jeep CL550', 'Audi A8', 'Audi Q7',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Alto',
#        'Mahindra Scorpio S10', 'Mahindra Scorpio S10',
#        'Maruti Suzuki Alto', 'Hyundai i20 Sportz', 'Hyundai i20 Sportz',
#        'Hyundai i20 Sportz', 'Maruti Suzuki Alto', 'Maruti Suzuki Vitara',
#        'Maruti Suzuki Alto', 'Mahindra Bolero DI', 'Maruti Suzuki Swift',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Swift',
#        'Maruti Suzuki Wagon', 'Maruti Suzuki Wagon', 'Toyota Innova 2.0',
#        'Renault Lodgy 85', 'Skoda Yeti Ambition', 'Maruti Suzuki Baleno',
#        'Renault Duster 110', 'Renault Duster 85', 'Honda City 1.5',
#        'Maruti Suzuki Alto', 'Maruti Suzuki Dzire', 'Honda Amaze',
#        'Honda Amaze 1.5', 'Honda City', 'Datsun Redi GO',
#        'Maruti Suzuki SX4', 'Mitsubishi Pajero Sport',
#        'Mahindra Bolero DI', 'Maruti Suzuki Swift',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Swift',
#        'Maruti Suzuki Wagon', 'Maruti Suzuki Wagon',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Swift', 'Honda City ZX',
#        'Maruti Suzuki Wagon', 'Ford Figo', 'Hyundai Eon',
#        'Tata Indigo eCS', 'Ford EcoSport Ambiente', 'Tata Indigo eCS',
#        'Mahindra Scorpio SLE', 'Volkswagen Polo Highline',
#        'Skoda Fabia Classic', 'Maruti Suzuki Stingray',
#        'Chevrolet Spark LS', 'Renault Duster 110PS', 'Honda City',
#        'Mini Cooper S', 'Datsun Redi GO', 'Skoda Fabia 1.2L',
#        'Honda Amaze', 'Honda Amaze', 'Renault Duster', 'Mini Cooper S',
#        'Mahindra Scorpio S4', 'Mahindra Scorpio VLX',
#        'Mahindra Quanto C8', 'Ford EcoSport', 'Honda Brio',
#        'Volkswagen Vento Highline', 'Hyundai i20 Magna',
#        'Toyota Corolla Altis', 'Hyundai Verna Transform',
#        'Toyota Corolla Altis', 'Honda City 1.5', 'Hyundai Elite i20',
#        'Skoda Fabia 1.2L', 'BMW 3 Series', 'Maruti Suzuki A',
#        'Toyota Etios GD', 'Ford Figo Diesel', 'Maruti Suzuki Swift',
#        'Chevrolet Beat LT', 'BMW 7 Series', 'Mahindra XUV500 W8',
#        'Hyundai i10 Magna', 'Hyundai Verna Fluidic',
#        'Maruti Suzuki Swift', 'Maruti Suzuki Ertiga',
#        'Ford EcoSport Titanium', 'Maruti Suzuki Ertiga',
#        'Maruti Suzuki Ertiga', 'Maruti Suzuki Alto', 'Hyundai Grand i10',
#        'Honda Amaze 1.2', 'Hyundai i20 Asta', 'Ford Figo Diesel',
#        'Maruti Suzuki Eeco', 'Maruti Suzuki Ertiga',
#        'Maruti Suzuki Esteem', 'Maruti Suzuki Ritz',
#        'Maruti Suzuki Dzire', 'Maruti Suzuki Ritz', 'Maruti Suzuki Swift',
#        'Maruti Suzuki Dzire', 'Toyota Etios Liva', 'Hyundai i20 Sportz',
#        'Chevrolet Spark', 'Maruti Suzuki Alto', 'Nissan Micra XV',
#        'Maruti Suzuki Swift', 'Maruti Suzuki Alto', 'Honda Amaze 1.5',
#        'Maruti Suzuki Alto', 'Chevrolet Beat', 'Honda City 1.5',
#        'Ford EcoSport Trend', 'Hyundai i20 Asta', 'Maruti Suzuki Swift',
#        'Tata Indica V2', 'Hindustan Motors Ambassador',
#        'Toyota Corolla Altis', 'Toyota Corolla Altis',
#        'Toyota Innova 2.5', 'Volkswagen Jetta Highline',
#        'Volkswagen Polo Comfortline', 'Volkswagen Polo',
#        'Mahindra Scorpio', 'Renault Duster', 'Honda Amaze',
#        'Nissan Sunny', 'Hyundai Elite i20', 'Renault Kwid',
#        'Renault Duster', 'Ford EcoSport', 'Renault Duster',
#        'Mahindra Scorpio VLX', 'Maruti Suzuki Alto', 'Chevrolet Spark LT',
#        'Datsun Redi GO', 'Maruti Suzuki Swift', 'Fiat Punto Emotion',
#        'Maruti Suzuki Swift', 'Toyota Etios GD', 'Hyundai i20 Sportz',
#        'Hyundai i10 Sportz', 'Chevrolet Beat LT', 'Chevrolet Beat LS',
#        'Chevrolet Beat LT', 'Mahindra Scorpio VLX', 'Tata Indigo CS',
#        'Toyota Corolla Altis', 'Honda City 1.5', 'Maruti Suzuki Swift',
#        'Hyundai Eon Era', 'Mahindra Scorpio S10', 'Mahindra XUV500',
#        'Honda Brio', 'Ford Fiesta', 'Honda Amaze', 'Honda City',
#        'Maruti Suzuki Wagon', 'Honda City', 'Hyundai i20',
#        'Tata Indigo eCS', 'Hyundai Fluidic Verna', 'Mahindra Quanto C8',
#        'Fiat Petra ELX', 'Skoda Fabia 1.2L', 'Mini Cooper S',
#        'Hyundai Santro Xing', 'Maruti Suzuki Ciaz', 'Maruti Suzuki Zen',
#        'Honda City', 'Hyundai Creta 1.6', 'Mahindra Scorpio SLX',
#        'Mahindra Scorpio SLE', 'Toyota Innova 2.5', 'Maruti Suzuki Alto',
#        'Maruti Suzuki Wagon', 'Tata Nano Cx', 'Maruti Suzuki Alto',
#        'Maruti Suzuki Wagon', 'Maruti Suzuki Swift', 'Tata Sumo Victa',
#        'Maruti Suzuki Wagon', 'Maruti Suzuki Alto',
#        'Volkswagen Passat Diesel', 'Renault Scala RxL',
#        'Mahindra Quanto C8', 'Hyundai Grand i10', 'Hyundai i20 Active',
#        'Mahindra Xylo E4', 'Mahindra Jeep MM', 'Renault Duster 110PS',
#        'Mahindra Bolero SLE', 'Force Motors Force', 'Maruti Suzuki SX4',
#        'Mahindra Jeep CL550', 'Maruti Suzuki Alto', 'Mahindra Jeep CL550',
#        'Toyota Etios', 'Volkswagen Polo', 'Honda City ZX',
#        'Maruti Suzuki Wagon', 'Honda City VX', 'Mahindra Thar CRDe',
#        'Mitsubishi Pajero Sport', 'Audi A4 1.8', 'Mercedes Benz GLA',
#        'Land Rover Freelander', 'Renault Kwid RXT', 'Tata Aria Pleasure',
#        'Mercedes Benz B', 'Datsun GO T', 'Tata Indigo eCS',
#        'Tata Indigo eCS', 'Honda Jazz VX', 'Honda Amaze 1.2',
#        'Honda Amaze', 'Honda City', 'Honda City', 'Honda Amaze',
#        'Audi A4 1.8', 'Force Motors Force', 'Mahindra Scorpio S4',
#        'Hyundai i20 Active', 'Mini Cooper S', 'Maruti Suzuki Ciaz',
#        'Chevrolet Tavera Neo', 'Honda Amaze', 'Hyundai Eon Sportz',
#        'Tata Sumo Gold', 'Maruti Suzuki Wagon', 'Maruti Suzuki Esteem',
#        'Maruti Suzuki Eeco', 'Chevrolet Enjoy 1.4', 'Hyundai i20 Asta',
#        'Ford Figo Diesel', 'Maruti Suzuki Eeco', 'Maruti Suzuki Ertiga',
#        'Maruti Suzuki Esteem', 'Maruti Suzuki Ritz',
#        'Maruti Suzuki Dzire', 'Maruti Suzuki Ritz', 'Maruti Suzuki SX4',
#        'Maruti Suzuki Wagon', 'Mini Cooper S', 'Nissan Terrano XL',
#        'Renault Duster 85', 'Renault Duster 85', 'Renault Duster 85',
#        'Maruti Suzuki Dzire', 'Renault Kwid RXT', 'Maruti Suzuki Maruti',
#        'Renault Kwid 1.0', 'Renault Lodgy 85', 'Renault Scala RxL',
#        'Hyundai Grand i10', 'Maruti Suzuki Swift', 'Chevrolet Beat LS',
#        'Tata Indigo eCS', 'Hyundai Santro Xing', 'Hyundai Fluidic Verna',
#        'Chevrolet Beat LS', 'Mahindra Quanto C8', 'Fiat Petra ELX',
#        'Chevrolet Beat LS', 'Skoda Fabia 1.2L', 'Ford EcoSport Titanium',
#        'Hyundai Accent GLX', 'Mahindra TUV300 T4', 'Mini Cooper S',
#        'Mini Cooper S', 'Tata Indica V2', 'Mini Cooper S',
#        'Tata Indigo CS', 'Maruti Suzuki Swift', 'Mahindra Scorpio VLX',
#        'Honda Accord', 'Mahindra Scorpio S4', 'Chevrolet Tavera Neo',
#        'Ford EcoSport Titanium', 'Maruti Suzuki Ertiga', 'Honda Amaze',
#        'Maruti Suzuki Dzire', 'Honda City', 'Mahindra Scorpio 2.6',
#        'Maruti Suzuki Dzire', 'Honda City', 'Honda Mobilio',
#        'Toyota Corolla Altis', 'Honda City', 'Skoda Laura',
#        'Renault Duster', 'Maruti Suzuki Ertiga', 'Maruti Suzuki Dzire',
#        'Mahindra XUV500', 'Hyundai Verna Fluidic', 'Maruti Suzuki Vitara',
#        'Maruti Suzuki Wagon', 'Mahindra Scorpio', 'Honda Amaze',
#        'Mahindra XUV500', 'Mahindra Scorpio', 'Skoda Laura',
#        'Volkswagen Polo', 'Hyundai Elite i20', 'Tata Manza Aura',
#        'Chevrolet Sail UVA', 'Renault Duster 110',
#        'Hyundai Verna Fluidic', 'Audi A4 2.0', 'Hyundai Elantra SX',
#        'Mahindra Scorpio VLX', 'Mahindra KUV100 K8', 'Renault Scala RxL',
#        'Mahindra Quanto C8', 'Hyundai Grand i10', 'Hyundai i20 Active',
#        'Mahindra Xylo E4', 'Hyundai Grand i10', 'Hyundai i20',
#        'Hyundai Eon', 'Hyundai i10', 'Hyundai i20 Active',
#        'Datsun Redi GO', 'Toyota Etios Liva', 'Hyundai Accent',
#        'Hyundai Verna', 'Maruti Suzuki Swift', 'Toyota Fortuner',
#        'Hyundai i10 Sportz', 'Mahindra Bolero Power', 'Mahindra XUV500',
#        'Honda City 1.5', 'Chevrolet Spark LT', 'Mahindra Jeep MM',
#        'Renault Duster 110PS', 'Mahindra XUV500', 'Tata Indigo eCS',
#        'Mahindra Bolero SLE', 'Force Motors Force',
#        'Skoda Rapid Elegance', 'Tata Vista Quadrajet',
#        'Maruti Suzuki Alto', 'Maruti Suzuki SX4', 'Maruti Suzuki Zen',
#        'Mahindra Jeep CL550', 'Hyundai i10 Magna', 'Maruti Suzuki Alto',
#        'Maruti Suzuki Swift', 'Honda City ZX', 'Mahindra Jeep CL550',
#        'Mahindra Jeep MM', 'Chevrolet Beat Diesel', 'Honda City 1.5',
#        'Hyundai Verna 1.4', 'Toyota Innova 2.5', 'Maruti Suzuki Maruti',
#        'Toyota Etios', 'Volkswagen Polo', 'Maruti Suzuki Swift',
#        'Hyundai Elite i20', 'Maruti Suzuki Swift', 'Maruti Suzuki Versa',
#        'Tata Indigo LX', 'Volkswagen Vento Konekt', 'Mercedes Benz C',
#        'Maruti Suzuki Ertiga', 'Honda City', 'Hyundai Santro Xing',
#        'Maruti Suzuki Omni', 'Hyundai Sonata Transform',
#        'Hyundai Elite i20', 'Volkswagen Vento Konekt',
#        'Maruti Suzuki Alto', 'Maruti Suzuki Alto', 'Honda Jazz S',
#        'Hyundai Grand i10', 'Maruti Suzuki Zen', 'Mahindra Scorpio W',
#        'Maruti Suzuki Alto', 'Hyundai Grand i10', 'Mahindra XUV500 W8',
#        'Hyundai Creta 1.6', 'Hyundai i20 Magna', 'Renault Duster 85',
#        'Hyundai Grand i10', 'Honda Brio V', 'Mahindra TUV300 T4',
#        'Chevrolet Spark LS', 'Mahindra TUV300 T8', 'Maruti Suzuki Swift',
#        'Nissan X Trail', 'Maruti Suzuki Alto', 'Ford Ikon 1.3',
#        'Toyota Fortuner 3.0', 'Tata Manza ELAN', 'Mercedes Benz A',
#        'Chevrolet Beat LS', 'Ford EcoSport Trend', 'Tata Indigo LS',
#        'Hyundai i20 Magna', 'Volkswagen Vento Highline',
#        'Renault Kwid RXT', 'Ford EcoSport Titanium', 'Honda Amaze 1.5',
#        'Hyundai Verna 1.6', 'BMW 5 Series', 'Skoda Superb 1.8',
#        'Audi Q3 2.0', 'Mahindra Bolero DI', 'Mahindra Scorpio S10',
#        'Ford Figo Duratorq', 'Maruti Suzuki Wagon',
#        'Mahindra Logan Diesel', 'Tata Nano GenX', 'Mahindra TUV300 T4',
#        'Mahindra TUV300 T4', 'Hyundai Elite i20', 'Hyundai Elite i20',
#        'Honda City SV', 'Maruti Suzuki Baleno', 'Ford Figo Petrol',
#        'Mahindra Scorpio S10', 'Honda City', 'Hyundai Elite i20',
#        'Maruti Suzuki Versa', 'Hyundai Eon Era',
#        'Mitsubishi Pajero Sport', 'Hyundai i10 Magna',
#        'Toyota Corolla H2', 'Maruti Suzuki Swift', 'Tata Indigo CS',
#        'Mahindra Scorpio S10', 'Mahindra Scorpio S10',
#        'Hyundai Xcent Base', 'Honda City', 'Hyundai Accent Executive',
#        'Maruti Suzuki Baleno', 'Tata Zest XE', 'Maruti Suzuki Dzire',
#        'Tata Sumo Gold', 'Toyota Corolla Altis', 'Maruti Suzuki Eeco',
#        'Toyota Fortuner 3.0', 'Mahindra XUV500 W6', 'Tata Tigor Revotron',
#        'Maruti Suzuki 800', 'Maruti Suzuki Ertiga', 'Maruti Suzuki Versa',
#        'Honda Mobilio S', 'Maruti Suzuki Ertiga', 'Maruti Suzuki Vitara',
#        'Hyundai Verna 1.6', 'Maruti Suzuki Swift', 'Toyota Fortuner 3.0',
#        'Maruti Suzuki Omni', 'Honda Amaze', 'Tata Indica',
#        'Hyundai Santro Xing', 'Maruti Suzuki Zen', 'Maruti Suzuki Wagon',
#        'Maruti Suzuki Wagon', 'Honda Brio VX', 'Maruti Suzuki Zen',
#        'Maruti Suzuki Zen', 'Maruti Suzuki Wagon', 'Maruti Suzuki Alto',
#        'Renault Kwid RXT', 'Tata Nano Lx', 'Jaguar XE XE',
#        'Hyundai Eon Magna', 'Honda City 1.5',
#        'Hindustan Motors Ambassador', 'Maruti Suzuki Ritz',
#        'Hyundai Grand i10', 'Hyundai Eon D', 'Maruti Suzuki Swift',
#        'Maruti Suzuki Wagon', 'Honda Amaze 1.2', 'Maruti Suzuki Estilo',
#        'Maruti Suzuki Vitara', 'Maruti Suzuki Eeco', 'Hyundai Creta 1.6',
#        'Mahindra Scorpio Vlx', 'Maruti Suzuki Ertiga',
#        'Mitsubishi Lancer 1.8', 'Maruti Suzuki Maruti',
#        'Maruti Suzuki Alto', 'Hyundai Grand i10', 'Hyundai Eon D',
#        'Ford Fiesta SXi', 'Maruti Suzuki Ritz', 'Hyundai Verna Fluidic',
#        'Maruti Suzuki Wagon', 'Maruti Suzuki Estilo', 'Audi A6 2.0',
#        'Maruti Suzuki Wagon', 'Maruti Suzuki Wagon',
#        'Maruti Suzuki Wagon', 'Maruti Suzuki Alto',
#        'Maruti Suzuki Baleno', 'Hyundai Verna 1.6', 'Maruti Suzuki Swift',
#        'Hyundai Getz Prime', 'Hyundai Santro', 'Hyundai Getz Prime',
#        'Chevrolet Beat PS', 'Ford EcoSport Trend', 'Maruti Suzuki Dzire',
#        'Hyundai Fluidic Verna', 'Tata Indica V2', 'BMW X1 xDrive20d',
#        'Hyundai i20 Asta', 'Honda City 1.5', 'Tata Nano',
#        'Chevrolet Cruze LTZ', 'Hyundai Verna Fluidic',
#        'Maruti Suzuki Swift', 'Mahindra XUV500 W10', 'Maruti Suzuki Alto',
#        'Hyundai Accent GLE', 'Force Motors One', 'Maruti Suzuki Alto',
#        'Chevrolet Spark 1.0', 'Hyundai i10', 'Toyota Etios Liva',
#        'Renault Duster 85PS', 'Chevrolet Enjoy', 'Maruti Suzuki Alto',
#        'BMW 5 Series', 'Toyota Etios Liva', 'Mahindra Jeep MM',
#        'Chevrolet Beat LS', 'Chevrolet Cruze LTZ',
#        'Jeep Wrangler Unlimited', 'Maruti Suzuki Ertiga',
#        'Hyundai Verna VGT', 'Maruti Suzuki Omni', 'Maruti Suzuki Celerio',
#        'Tata Zest Quadrajet', 'Mahindra XUV500 W6', 'Tata Indigo CS',
#        'Hyundai i10 Era', 'Tata Indigo eCS', 'Tata Indigo LX',
#        'Tata Indigo eCS', 'Tata Indigo Marina', 'Hyundai Xcent SX',
#        'Hyundai Eon Magna', 'Renault Duster 85', 'Maruti Suzuki Alto',
#        'Tata Nano LX', 'Renault Duster 110', 'Maruti Suzuki Wagon',
#        'Maruti Suzuki Swift', 'Maruti Suzuki Ertiga',
#        'Maruti Suzuki Swift', 'Maruti Suzuki Alto', 'Hyundai i20 Magna',
#        'Hyundai i10 Magna', 'Tata Zest XE', 'Mahindra Xylo E8',
#        'Toyota Corolla Altis', 'Tata Manza Aqua', 'Renault Kwid 1.0',
#        'Tata Venture EX', 'Maruti Suzuki Swift', 'Skoda Octavia Classic',
#        'Maruti Suzuki Omni', 'Chevrolet Beat Diesel', 'Tata Sumo Gold',
#        'Hyundai Verna 1.6', 'Tata Sumo Gold', 'Mahindra Scorpio 2.6',
#        'Maruti Suzuki Zen', 'Maruti Suzuki Swift', 'Mahindra Scorpio SLX',
#        'Hyundai Grand i10', 'Hyundai Elite i20', 'Ford Ikon 1.6',
#        'Toyota Innova 2.5', 'Nissan Sunny XL', 'Chevrolet Beat LT',
#        'Maruti Suzuki Alto', 'Maruti Suzuki Swift', 'Maruti Suzuki Swift',
#        'Maruti Suzuki Swift', 'Toyota Innova 2.0', 'Maruti Suzuki Swift',
#        'Hyundai Elite i20', 'Mahindra XUV500 W10',
#        'Volkswagen Polo Trendline', 'Toyota Etios Liva',
#        'Mahindra TUV300 T4', 'Hyundai Elite i20', 'Hyundai Santro Xing',
#        'Maruti Suzuki Zen', 'Maruti Suzuki Ciaz', 'Hyundai Eon Era',
#        'Hyundai Elantra 1.8', 'Maruti Suzuki Swift', 'Maruti Suzuki Zen',
#        'Hyundai Eon Era', 'Hyundai Grand i10', 'Hyundai Verna Fluidic',
#        'Ford EcoSport Trend', 'Hyundai i20 Magna',
#        'Chevrolet Beat Diesel', 'Tata Indica eV2', 'Jaguar XF 2.2',
#        'Audi Q5 2.0', 'BMW 3 Series', 'Maruti Suzuki Swift',
#        'BMW X1 sDrive20d', 'Maruti Suzuki S', 'Maruti Suzuki Ertiga',
#        'Maruti Suzuki Alto', 'Honda City SV',
#        'Volkswagen Vento Comfortline', 'Honda City 1.5', 'Audi A4 2.0',
#        'Mahindra KUV100', 'Tata Zest XE', 'Mahindra XUV500 W8',
#        'Maruti Suzuki Swift', 'Tata Sumo Gold', 'Maruti Suzuki Swift',
#        'Mahindra Scorpio 2.6', 'Maruti Suzuki Omni',
#        'Mitsubishi Pajero Sport', 'Renault Duster',
#        'Volkswagen Jetta Comfortline', 'Maruti Suzuki Ertiga',
#        'Audi A4 2.0', 'Volvo S80 Summum', 'Toyota Corolla Altis',
#        'Mitsubishi Pajero Sport', 'Chevrolet Beat LT', 'BMW X1',
#        'Datsun Redi GO', 'Mercedes Benz C', 'Mahindra Scorpio SLX',
#        'Volkswagen Vento Comfortline', 'Tata Indigo CS',
#        'Ford Figo Petrol', 'Honda City ZX', 'Maruti Suzuki Wagon',
#        'Ford EcoSport Trend', 'Maruti Suzuki Swift', 'Maruti Suzuki Omni',
#        'Maruti Suzuki Zen', 'Renault Duster RxL', 'Maruti Suzuki Swift',
#        'Maruti Suzuki Baleno', 'Honda WR V', 'Tata Indigo CS',
#        'Renault Duster 110', 'Mahindra Scorpio LX', 'Maruti Suzuki Zen',
#        'Maruti Suzuki Wagon', 'Maruti Suzuki SX4', 'Audi A3 Cabriolet',
#        'Hyundai Eon D', 'Maruti Suzuki Zen', 'Mahindra Scorpio SLX',
#        'Hyundai Santro AE', 'Maruti Suzuki Swift', 'Mahindra Scorpio S4',
#        'Mahindra Xylo D2', 'Hyundai Santro', 'Chevrolet Beat LT',
#        'Maruti Suzuki Swift', 'Mahindra XUV500 W8', 'Toyota Fortuner 3.0',
#        'Maruti Suzuki Alto', 'Hyundai Getz GLE', 'Maruti Suzuki Swift',
#        'Hyundai Creta 1.6', 'Hyundai Santro Xing', 'Hyundai Santro Xing',
#        'Mahindra Xylo D2', 'Hyundai Santro Xing', 'Tata Indica V2',
#        'Hyundai i10 Sportz', 'Hyundai Grand i10', 'Hyundai Santro Xing',
#        'Honda City 1.5', 'Nissan Micra XL', 'Honda City 1.5',
#        'Maruti Suzuki Alto', 'Maruti Suzuki Wagon',
#        'Maruti Suzuki Ertiga', 'Tata Indica eV2', 'Maruti Suzuki Omni',
#        'Hyundai Eon Era', 'Hyundai Eon', 'Maruti Suzuki Swift',
#        'Hyundai Verna 1.6', 'Chevrolet Tavera LS', 'Tata Tiago Revotron',
#        'Tata Tiago Revotorq', 'Maruti Suzuki Zen', 'Mahindra KUV100 K8',
#        'Ford EcoSport Titanium', 'Hindustan Motors Ambassador',
#        'Ford Fusion 1.4', 'Hyundai Santro Xing', 'Hyundai Santro',
#        'Fiat Linea Emotion', 'Ford Ikon 1.3', 'Maruti Suzuki Omni',
#        'Tata Indica V2', 'Mahindra Scorpio S4', 'Hyundai Santro Xing',
#        'Mahindra Xylo D2', 'Hyundai Grand i10', 'Maruti Suzuki Alto',
#        'Toyota Corolla', 'Hyundai Eon Magna', 'Tata Sumo Grande',
#        'Maruti Suzuki Swift', 'Volkswagen Polo Highline1.2L',
#        'Maruti Suzuki Alto', 'Tata Tiago Revotron', 'Maruti Suzuki Swift',
#        'Maruti Suzuki Swift', 'Tata Indigo eCS', 'Chevrolet Beat LS',
#        'Mahindra Xylo E8', 'Hyundai Eon D', 'Tata Sumo Gold', 'Tata Nano',
#        'Hyundai Elite i20', 'Hyundai i10 Magna', 'Hyundai Creta',
#        'Volkswagen Polo', 'Maruti Suzuki Dzire', 'Tata Bolt XM',
#        'Maruti Suzuki Alto', 'Maruti Suzuki Alto', 'Maruti Suzuki Ritz',
#        'Maruti Suzuki Alto', 'Maruti Suzuki Dzire', 'Hyundai i20 Asta',
#        'Maruti Suzuki Swift', 'Tata Indica V2', 'Mahindra Scorpio VLX',
#        'Toyota Innova 2.5', 'Mahindra Xylo E8', 'Hyundai i20 Magna',
#        'Maruti Suzuki Omni', 'Mahindra KUV100', 'Mahindra KUV100 K8',
#        'Datsun Go Plus', 'Ford Endeavor 4x4', 'Tata Indica V2',
#        'Hyundai Santro Xing', 'Maruti Suzuki Wagon',
#        'Maruti Suzuki Swift', 'Maruti Suzuki Alto', 'Toyota Innova 2.5',
#        'Maruti Suzuki Alto', 'Maruti Suzuki Alto',
#        'Volkswagen Polo Highline1.2L', 'Mahindra Logan',
#        'Maruti Suzuki 800', 'Mahindra Scorpio', 'Chevrolet Sail 1.2',
#        'Hyundai Santro AE', 'Maruti Suzuki Wagon', 'Hyundai Eon',
#        'Tata Manza', 'Toyota Etios G', 'Hyundai Getz Prime',
#        'Toyota Qualis', 'Hyundai Santro Xing', 'Tata Indica eV2',
#        'Honda City 1.5', 'Tata Zest XE', 'Mahindra Quanto C4',
#        'Tata Indigo eCS', 'Maruti Suzuki Swift', 'Hyundai Elite i20',
#        'Hyundai i20 Select', 'Chevrolet Tavera Neo',
#        'Maruti Suzuki Dzire', 'Hyundai Elite i20', 'Honda City VX',
#        'Maruti Suzuki Dzire', 'Hyundai Getz', 'Mercedes Benz C',
#        'Maruti Suzuki Alto', 'Maruti Suzuki Swift', 'Skoda Fabia',
#        'Maruti Suzuki Ritz', 'Tata Indica V2', 'Toyota Corolla Altis',
#        'Tata Zest XM', 'Mahindra Quanto C8'], dtype=object)

# %%
car.to_dict()
# Out:
# {'name': {0: 'Hyundai Santro Xing',
#   1: 'Mahindra Jeep CL550',
#   2: 'Hyundai Grand i10',
#   3: 'Ford EcoSport Titanium',
#   4: 'Ford Figo',
#   5: 'Hyundai Eon',
#   6: 'Ford EcoSport Ambiente',
#   7: 'Maruti Suzuki Alto',
#   8: 'Skoda Fabia Classic',
#   9: 'Maruti Suzuki Stingray',
#   10: 'Hyundai Elite i20',
#   11: 'Mahindra Scorpio SLE',
#   12: 'Hyundai Santro Xing',
#   13: 'Mahindra Jeep CL550',
#   14: 'Audi A8',
#   15: 'Audi Q7',
#   16: 'Mahindra Scorpio S10',
#   17: 'Maruti Suzuki Alto',
#   18: 'Mahindra Scorpio S10',
#   19: 'Mahindra Scorpio S10',
#   20: 'Maruti Suzuki Alto',
#   21: 'Hyundai i20 Sportz',
#   22: 'Hyundai i20 Sportz',
#   23: 'Hyundai i20 Sportz',
#   24: 'Maruti Suzuki Alto',
#   25: 'Maruti Suzuki Vitara',
#   26: 'Maruti Suzuki Alto',
#   27: 'Mahindra Bolero DI',
#   28: 'Maruti Suzuki Swift',
#   29: 'Mahindra Scorpio S10',
#   30: 'Maruti Suzuki Swift',
#   31: 'Maruti Suzuki Wagon',
#   32: 'Maruti Suzuki Wagon',
#   33: 'Toyota Innova 2.0',
#   34: 'Renault Lodgy 85',
#   35: 'Skoda Yeti Ambition',
#   36: 'Maruti Suzuki Baleno',
#   37: 'Renault Duster 110',
#   38: 'Renault Duster 85',
#   39: 'Honda City 1.5',
#   40: 'Maruti Suzuki Alto',
#   41: 'Maruti Suzuki Dzire',
#   42: 'Honda Amaze',
#   43: 'Honda Amaze 1.5',
#   44: 'Honda City',
#   45: 'Datsun Redi GO',
#   46: 'Maruti Suzuki SX4',
#   47: 'Mitsubishi Pajero Sport',
#   48: 'Mahindra Bolero DI',
#   49: 'Maruti Suzuki Swift',
#   50: 'Mahindra Scorpio S10',
#   51: 'Maruti Suzuki Swift',
#   52: 'Maruti Suzuki Wagon',
#   53: 'Maruti Suzuki Wagon',
#   54: 'Mahindra Scorpio S10',
#   55: 'Maruti Suzuki Swift',
#   56: 'Honda City ZX',
#   57: 'Maruti Suzuki Wagon',
#   58: 'Ford Figo',
#   59: 'Hyundai Eon',
#   60: 'Tata Indigo eCS',
#   61: 'Ford EcoSport Ambiente',
#   62: 'Tata Indigo eCS',
#   63: 'Mahindra Scorpio SLE',
#   64: 'Volkswagen Polo Highline',
#   65: 'Skoda Fabia Classic',
#   66: 'Maruti Suzuki Stingray',
#   67: 'Chevrolet Spark LS',
#   68: 'Renault Duster 110PS',
#   69: 'Honda City',
#   70: 'Mini Cooper S',
#   71: 'Datsun Redi GO',
#   72: 'Skoda Fabia 1.2L',
#   73: 'Honda Amaze',
#   74: 'Honda Amaze',
#   75: 'Renault Duster',
#   76: 'Mini Cooper S',
#   77: 'Mahindra Scorpio S4',
#   78: 'Mahindra Scorpio VLX',
#   79: 'Mahindra Quanto C8',
#   80: 'Ford EcoSport',
#   81: 'Honda Brio',
#   82: 'Volkswagen Vento Highline',
#   83: 'Hyundai i20 Magna',
#   84: 'Toyota Corolla Altis',
#   85: 'Hyundai Verna Transform',
#   86: 'Toyota Corolla Altis',
#   87: 'Honda City 1.5',
#   88: 'Hyundai Elite i20',
#   89: 'Skoda Fabia 1.2L',
#   90: 'BMW 3 Series',
#   91: 'Maruti Suzuki A',
#   92: 'Toyota Etios GD',
#   93: 'Ford Figo Diesel',
#   94: 'Maruti Suzuki Swift',
#   95: 'Chevrolet Beat LT',
#   96: 'BMW 7 Series',
#   97: 'Mahindra XUV500 W8',
#   98: 'Hyundai i10 Magna',
#   99: 'Hyundai Verna Fluidic',
#   100: 'Maruti Suzuki Swift',
#   101: 'Maruti Suzuki Ertiga',
#   102: 'Ford EcoSport Titanium',
#   103: 'Maruti Suzuki Ertiga',
#   104: 'Maruti Suzuki Ertiga',
#   105: 'Maruti Suzuki Alto',
#   106: 'Hyundai Grand i10',
#   107: 'Honda Amaze 1.2',
#   108: 'Hyundai i20 Asta',
#   109: 'Ford Figo Diesel',
#   110: 'Maruti Suzuki Eeco',
#   111: 'Maruti Suzuki Ertiga',
#   112: 'Maruti Suzuki Esteem',
#   113: 'Maruti Suzuki Ritz',
#   114: 'Maruti Suzuki Dzire',
#   115: 'Maruti Suzuki Ritz',
#   116: 'Maruti Suzuki Swift',
#   117: 'Maruti Suzuki Dzire',
#   118: 'Toyota Etios Liva',
#   119: 'Hyundai i20 Sportz',
#   120: 'Chevrolet Spark',
#   121: 'Maruti Suzuki Alto',
#   122: 'Nissan Micra XV',
#   123: 'Maruti Suzuki Swift',
#   124: 'Maruti Suzuki Alto',
#   125: 'Honda Amaze 1.5',
#   126: 'Maruti Suzuki Alto',
#   127: 'Chevrolet Beat',
#   128: 'Honda City 1.5',
#   129: 'Ford EcoSport Trend',
#   130: 'Hyundai i20 Asta',
#   131: 'Maruti Suzuki Swift',
#   132: 'Tata Indica V2',
#   133: 'Hindustan Motors Ambassador',
#   134: 'Toyota Corolla Altis',
#   135: 'Toyota Corolla Altis',
#   136: 'Toyota Innova 2.5',
#   137: 'Volkswagen Jetta Highline',
#   138: 'Volkswagen Polo Comfortline',
#   139: 'Volkswagen Polo',
#   140: 'Mahindra Scorpio',
#   141: 'Renault Duster',
#   142: 'Honda Amaze',
#   143: 'Nissan Sunny',
#   144: 'Hyundai Elite i20',
#   145: 'Renault Kwid',
#   146: 'Renault Duster',
#   147: 'Ford EcoSport',
#   148: 'Renault Duster',
#   149: 'Mahindra Scorpio VLX',
#   150: 'Maruti Suzuki Alto',
#   151: 'Chevrolet Spark LT',
#   152: 'Datsun Redi GO',
#   153: 'Maruti Suzuki Swift',
#   154: 'Fiat Punto Emotion',
#   155: 'Maruti Suzuki Swift',
#   156: 'Toyota Etios GD',
#   157: 'Hyundai i20 Sportz',
#   158: 'Hyundai i10 Sportz',
#   159: 'Chevrolet Beat LT',
#   160: 'Chevrolet Beat LS',
#   161: 'Chevrolet Beat LT',
#   162: 'Mahindra Scorpio VLX',
#   163: 'Tata Indigo CS',
#   164: 'Toyota Corolla Altis',
#   165: 'Honda City 1.5',
#   166: 'Maruti Suzuki Swift',
#   167: 'Hyundai Eon Era',
#   168: 'Mahindra Scorpio S10',
#   169: 'Mahindra XUV500',
#   170: 'Honda Brio',
#   171: 'Ford Fiesta',
#   172: 'Honda Amaze',
#   173: 'Honda City',
#   174: 'Maruti Suzuki Wagon',
#   175: 'Honda City',
#   176: 'Hyundai i20',
#   177: 'Tata Indigo eCS',
#   178: 'Hyundai Fluidic Verna',
#   179: 'Mahindra Quanto C8',
#   180: 'Fiat Petra ELX',
#   181: 'Skoda Fabia 1.2L',
#   182: 'Mini Cooper S',
#   183: 'Hyundai Santro Xing',
#   184: 'Maruti Suzuki Ciaz',
#   185: 'Maruti Suzuki Zen',
#   186: 'Honda City',
#   187: 'Hyundai Creta 1.6',
#   188: 'Mahindra Scorpio SLX',
#   189: 'Mahindra Scorpio SLE',
#   190: 'Toyota Innova 2.5',
#   191: 'Maruti Suzuki Alto',
#   192: 'Maruti Suzuki Wagon',
#   193: 'Tata Nano Cx',
#   194: 'Maruti Suzuki Alto',
#   195: 'Maruti Suzuki Wagon',
#   196: 'Maruti Suzuki Swift',
#   197: 'Tata Sumo Victa',
#   198: 'Maruti Suzuki Wagon',
#   199: 'Maruti Suzuki Alto',
#   200: 'Volkswagen Passat Diesel',
#   201: 'Renault Scala RxL',
#   202: 'Mahindra Quanto C8',
#   203: 'Hyundai Grand i10',
#   204: 'Hyundai i20 Active',
#   205: 'Mahindra Xylo E4',
#   206: 'Mahindra Jeep MM',
#   207: 'Renault Duster 110PS',
#   208: 'Mahindra Bolero SLE',
#   209: 'Force Motors Force',
#   210: 'Maruti Suzuki SX4',
#   211: 'Mahindra Jeep CL550',
#   212: 'Maruti Suzuki Alto',
#   213: 'Mahindra Jeep CL550',
#   214: 'Toyota Etios',
#   215: 'Volkswagen Polo',
#   216: 'Honda City ZX',
#   217: 'Maruti Suzuki Wagon',
#   218: 'Honda City VX',
#   219: 'Mahindra Thar CRDe',
#   220: 'Mitsubishi Pajero Sport',
#   221: 'Audi A4 1.8',
#   222: 'Mercedes Benz GLA',
#   223: 'Land Rover Freelander',
#   224: 'Renault Kwid RXT',
#   225: 'Tata Aria Pleasure',
#   226: 'Mercedes Benz B',
#   227: 'Datsun GO T',
#   228: 'Tata Indigo eCS',
#   229: 'Tata Indigo eCS',
#   230: 'Honda Jazz VX',
#   231: 'Honda Amaze 1.2',
#   232: 'Honda Amaze',
#   233: 'Honda City',
#   234: 'Honda City',
#   235: 'Honda Amaze',
#   236: 'Audi A4 1.8',
#   237: 'Force Motors Force',
#   238: 'Mahindra Scorpio S4',
#   239: 'Hyundai i20 Active',
#   240: 'Mini Cooper S',
#   241: 'Maruti Suzuki Ciaz',
#   242: 'Chevrolet Tavera Neo',
#   243: 'Honda Amaze',
#   244: 'Hyundai Eon Sportz',
#   245: 'Tata Sumo Gold',
#   246: 'Maruti Suzuki Wagon',
#   247: 'Maruti Suzuki Esteem',
#   248: 'Maruti Suzuki Eeco',
#   249: 'Chevrolet Enjoy 1.4',
#   250: 'Hyundai i20 Asta',
#   251: 'Ford Figo Diesel',
#   252: 'Maruti Suzuki Eeco',
#   253: 'Maruti Suzuki Ertiga',
#   254: 'Maruti Suzuki Esteem',
#   255: 'Maruti Suzuki Ritz',
#   256: 'Maruti Suzuki Dzire',
#   257: 'Maruti Suzuki Ritz',
#   258: 'Maruti Suzuki SX4',
#   259: 'Maruti Suzuki Wagon',
#   260: 'Mini Cooper S',
#   261: 'Nissan Terrano XL',
#   262: 'Renault Duster 85',
#   263: 'Renault Duster 85',
#   264: 'Renault Duster 85',
#   265: 'Maruti Suzuki Dzire',
#   266: 'Renault Kwid RXT',
#   267: 'Maruti Suzuki Maruti',
#   268: 'Renault Kwid 1.0',
#   269: 'Renault Lodgy 85',
#   270: 'Renault Scala RxL',
#   271: 'Hyundai Grand i10',
#   272: 'Maruti Suzuki Swift',
#   273: 'Chevrolet Beat LS',
#   274: 'Tata Indigo eCS',
#   275: 'Hyundai Santro Xing',
#   276: 'Hyundai Fluidic Verna',
#   277: 'Chevrolet Beat LS',
#   278: 'Mahindra Quanto C8',
#   279: 'Fiat Petra ELX',
#   280: 'Chevrolet Beat LS',
#   281: 'Skoda Fabia 1.2L',
#   282: 'Ford EcoSport Titanium',
#   283: 'Hyundai Accent GLX',
#   284: 'Mahindra TUV300 T4',
#   285: 'Mini Cooper S',
#   286: 'Mini Cooper S',
#   287: 'Tata Indica V2',
#   288: 'Mini Cooper S',
#   289: 'Tata Indigo CS',
#   290: 'Maruti Suzuki Swift',
#   291: 'Mahindra Scorpio VLX',
#   292: 'Honda Accord',
#   293: 'Mahindra Scorpio S4',
#   294: 'Chevrolet Tavera Neo',
#   295: 'Ford EcoSport Titanium',
#   296: 'Maruti Suzuki Ertiga',
#   297: 'Honda Amaze',
#   298: 'Maruti Suzuki Dzire',
#   299: 'Honda City',
#   300: 'Mahindra Scorpio 2.6',
#   301: 'Maruti Suzuki Dzire',
#   302: 'Honda City',
#   303: 'Honda Mobilio',
#   304: 'Toyota Corolla Altis',
#   305: 'Honda City',
#   306: 'Skoda Laura',
#   307: 'Renault Duster',
#   308: 'Maruti Suzuki Ertiga',
#   309: 'Maruti Suzuki Dzire',
#   310: 'Mahindra XUV500',
#   311: 'Hyundai Verna Fluidic',
#   312: 'Maruti Suzuki Vitara',
#   313: 'Maruti Suzuki Wagon',
#   314: 'Mahindra Scorpio',
#   315: 'Honda Amaze',
#   316: 'Mahindra XUV500',
#   317: 'Mahindra Scorpio',
#   318: 'Skoda Laura',
#   319: 'Volkswagen Polo',
#   320: 'Hyundai Elite i20',
#   321: 'Tata Manza Aura',
#   322: 'Chevrolet Sail UVA',
#   323: 'Renault Duster 110',
#   324: 'Hyundai Verna Fluidic',
#   325: 'Audi A4 2.0',
#   326: 'Hyundai Elantra SX',
#   327: 'Mahindra Scorpio VLX',
#   328: 'Mahindra KUV100 K8',
#   329: 'Renault Scala RxL',
#   330: 'Mahindra Quanto C8',
#   331: 'Hyundai Grand i10',
#   332: 'Hyundai i20 Active',
#   333: 'Mahindra Xylo E4',
#   334: 'Hyundai Grand i10',
#   335: 'Hyundai i20',
#   336: 'Hyundai Eon',
#   337: 'Hyundai i10',
#   338: 'Hyundai i20 Active',
#   339: 'Datsun Redi GO',
#   340: 'Toyota Etios Liva',
#   341: 'Hyundai Accent',
#   342: 'Hyundai Verna',
#   343: 'Maruti Suzuki Swift',
#   344: 'Toyota Fortuner',
#   345: 'Hyundai i10 Sportz',
#   346: 'Mahindra Bolero Power',
#   347: 'Mahindra XUV500',
#   348: 'Honda City 1.5',
#   349: 'Chevrolet Spark LT',
#   350: 'Mahindra Jeep MM',
#   351: 'Renault Duster 110PS',
#   352: 'Mahindra XUV500',
#   353: 'Tata Indigo eCS',
#   354: 'Mahindra Bolero SLE',
#   355: 'Force Motors Force',
#   356: 'Skoda Rapid Elegance',
#   357: 'Tata Vista Quadrajet',
#   358: 'Maruti Suzuki Alto',
#   359: 'Maruti Suzuki SX4',
#   360: 'Maruti Suzuki Zen',
#   361: 'Mahindra Jeep CL550',
#   362: 'Hyundai i10 Magna',
#   363: 'Maruti Suzuki Alto',
#   364: 'Maruti Suzuki Swift',
#   365: 'Honda City ZX',
#   366: 'Mahindra Jeep CL550',
#   367: 'Mahindra Jeep MM',
#   368: 'Chevrolet Beat Diesel',
#   369: 'Honda City 1.5',
#   370: 'Hyundai Verna 1.4',
#   371: 'Toyota Innova 2.5',
#   372: 'Maruti Suzuki Maruti',
#   373: 'Toyota Etios',
#   374: 'Volkswagen Polo',
#   375: 'Maruti Suzuki Swift',
#   376: 'Hyundai Elite i20',
#   377: 'Maruti Suzuki Swift',
#   378: 'Maruti Suzuki Versa',
#   379: 'Tata Indigo LX',
#   380: 'Volkswagen Vento Konekt',
#   381: 'Mercedes Benz C',
#   382: 'Maruti Suzuki Ertiga',
#   383: 'Honda City',
#   384: 'Hyundai Santro Xing',
#   385: 'Maruti Suzuki Omni',
#   386: 'Hyundai Sonata Transform',
#   387: 'Hyundai Elite i20',
#   388: 'Volkswagen Vento Konekt',
#   389: 'Maruti Suzuki Alto',
#   390: 'Maruti Suzuki Alto',
#   391: 'Honda Jazz S',
#   392: 'Hyundai Grand i10',
#   393: 'Maruti Suzuki Zen',
#   394: 'Mahindra Scorpio W',
#   395: 'Maruti Suzuki Alto',
#   396: 'Hyundai Grand i10',
#   397: 'Mahindra XUV500 W8',
#   398: 'Hyundai Creta 1.6',
#   399: 'Hyundai i20 Magna',
#   400: 'Renault Duster 85',
#   401: 'Hyundai Grand i10',
#   402: 'Honda Brio V',
#   403: 'Mahindra TUV300 T4',
#   404: 'Chevrolet Spark LS',
#   405: 'Mahindra TUV300 T8',
#   406: 'Maruti Suzuki Swift',
#   407: 'Nissan X Trail',
#   408: 'Maruti Suzuki Alto',
#   409: 'Ford Ikon 1.3',
#   410: 'Toyota Fortuner 3.0',
#   411: 'Tata Manza ELAN',
#   412: 'Mercedes Benz A',
#   413: 'Chevrolet Beat LS',
#   414: 'Ford EcoSport Trend',
#   415: 'Tata Indigo LS',
#   416: 'Hyundai i20 Magna',
#   417: 'Volkswagen Vento Highline',
#   418: 'Renault Kwid RXT',
#   419: 'Ford EcoSport Titanium',
#   420: 'Honda Amaze 1.5',
#   421: 'Hyundai Verna 1.6',
#   422: 'BMW 5 Series',
#   423: 'Skoda Superb 1.8',
#   424: 'Audi Q3 2.0',
#   425: 'Mahindra Bolero DI',
#   426: 'Mahindra Scorpio S10',
#   427: 'Ford Figo Duratorq',
#   428: 'Maruti Suzuki Wagon',
#   429: 'Mahindra Logan Diesel',
#   430: 'Tata Nano GenX',
#   431: 'Mahindra TUV300 T4',
#   432: 'Mahindra TUV300 T4',
#   433: 'Hyundai Elite i20',
#   434: 'Hyundai Elite i20',
#   435: 'Honda City SV',
#   436: 'Maruti Suzuki Baleno',
#   437: 'Ford Figo Petrol',
#   438: 'Mahindra Scorpio S10',
#   439: 'Honda City',
#   440: 'Hyundai Elite i20',
#   441: 'Maruti Suzuki Versa',
#   442: 'Hyundai Eon Era',
#   443: 'Mitsubishi Pajero Sport',
#   444: 'Hyundai i10 Magna',
#   445: 'Toyota Corolla H2',
#   446: 'Maruti Suzuki Swift',
#   447: 'Tata Indigo CS',
#   448: 'Mahindra Scorpio S10',
#   449: 'Mahindra Scorpio S10',
#   450: 'Hyundai Xcent Base',
#   451: 'Honda City',
#   452: 'Hyundai Accent Executive',
#   453: 'Maruti Suzuki Baleno',
#   454: 'Tata Zest XE',
#   455: 'Maruti Suzuki Dzire',
#   456: 'Tata Sumo Gold',
#   457: 'Toyota Corolla Altis',
#   458: 'Maruti Suzuki Eeco',
#   459: 'Toyota Fortuner 3.0',
#   460: 'Mahindra XUV500 W6',
#   461: 'Tata Tigor Revotron',
#   462: 'Maruti Suzuki 800',
#   463: 'Maruti Suzuki Ertiga',
#   464: 'Maruti Suzuki Versa',
#   465: 'Honda Mobilio S',
#   466: 'Maruti Suzuki Ertiga',
#   467: 'Maruti Suzuki Vitara',
#   468: 'Hyundai Verna 1.6',
#   469: 'Maruti Suzuki Swift',
#   470: 'Toyota Fortuner 3.0',
#   471: 'Maruti Suzuki Omni',
#   472: 'Honda Amaze',
#   473: 'Tata Indica',
#   474: 'Hyundai Santro Xing',
#   475: 'Maruti Suzuki Zen',
#   476: 'Maruti Suzuki Wagon',
#   477: 'Maruti Suzuki Wagon',
#   478: 'Honda Brio VX',
#   479: 'Maruti Suzuki Zen',
#   480: 'Maruti Suzuki Zen',
#   481: 'Maruti Suzuki Wagon',
#   482: 'Maruti Suzuki Alto',
#   483: 'Renault Kwid RXT',
#   484: 'Tata Nano Lx',
#   485: 'Jaguar XE XE',
#   486: 'Hyundai Eon Magna',
#   487: 'Honda City 1.5',
#   488: 'Hindustan Motors Ambassador',
#   489: 'Maruti Suzuki Ritz',
#   490: 'Hyundai Grand i10',
#   491: 'Hyundai Eon D',
#   492: 'Maruti Suzuki Swift',
#   493: 'Maruti Suzuki Wagon',
#   494: 'Honda Amaze 1.2',
#   495: 'Maruti Suzuki Estilo',
#   496: 'Maruti Suzuki Vitara',
#   497: 'Maruti Suzuki Eeco',
#   498: 'Hyundai Creta 1.6',
#   499: 'Mahindra Scorpio Vlx',
#   500: 'Maruti Suzuki Ertiga',
#   501: 'Mitsubishi Lancer 1.8',
#   502: 'Maruti Suzuki Maruti',
#   503: 'Maruti Suzuki Alto',
#   504: 'Hyundai Grand i10',
#   505: 'Hyundai Eon D',
#   506: 'Ford Fiesta SXi',
#   507: 'Maruti Suzuki Ritz',
#   508: 'Hyundai Verna Fluidic',
#   509: 'Maruti Suzuki Wagon',
#   510: 'Maruti Suzuki Estilo',
#   511: 'Audi A6 2.0',
#   512: 'Maruti Suzuki Wagon',
#   513: 'Maruti Suzuki Wagon',
#   514: 'Maruti Suzuki Wagon',
#   515: 'Maruti Suzuki Alto',
#   516: 'Maruti Suzuki Baleno',
#   517: 'Hyundai Verna 1.6',
#   518: 'Maruti Suzuki Swift',
#   519: 'Hyundai Getz Prime',
#   520: 'Hyundai Santro',
#   521: 'Hyundai Getz Prime',
#   522: 'Chevrolet Beat PS',
#   523: 'Ford EcoSport Trend',
#   524: 'Maruti Suzuki Dzire',
#   525: 'Hyundai Fluidic Verna',
#   526: 'Tata Indica V2',
#   527: 'BMW X1 xDrive20d',
#   528: 'Hyundai i20 Asta',
#   529: 'Honda City 1.5',
#   530: 'Tata Nano',
#   531: 'Chevrolet Cruze LTZ',
#   532: 'Hyundai Verna Fluidic',
#   533: 'Maruti Suzuki Swift',
#   534: 'Mahindra XUV500 W10',
#   535: 'Maruti Suzuki Alto',
#   536: 'Hyundai Accent GLE',
#   537: 'Force Motors One',
#   538: 'Maruti Suzuki Alto',
#   539: 'Chevrolet Spark 1.0',
#   540: 'Hyundai i10',
#   541: 'Toyota Etios Liva',
#   542: 'Renault Duster 85PS',
#   543: 'Chevrolet Enjoy',
#   544: 'Maruti Suzuki Alto',
#   545: 'BMW 5 Series',
#   546: 'Toyota Etios Liva',
#   547: 'Mahindra Jeep MM',
#   548: 'Chevrolet Beat LS',
#   549: 'Chevrolet Cruze LTZ',
#   550: 'Jeep Wrangler Unlimited',
#   551: 'Maruti Suzuki Ertiga',
#   552: 'Hyundai Verna VGT',
#   553: 'Maruti Suzuki Omni',
#   554: 'Maruti Suzuki Celerio',
#   555: 'Tata Zest Quadrajet',
#   556: 'Mahindra XUV500 W6',
#   557: 'Tata Indigo CS',
#   558: 'Hyundai i10 Era',
#   559: 'Tata Indigo eCS',
#   560: 'Tata Indigo LX',
#   561: 'Tata Indigo eCS',
#   562: 'Tata Indigo Marina',
#   563: 'Hyundai Xcent SX',
#   564: 'Hyundai Eon Magna',
#   565: 'Renault Duster 85',
#   566: 'Maruti Suzuki Alto',
#   567: 'Tata Nano LX',
#   568: 'Renault Duster 110',
#   569: 'Maruti Suzuki Wagon',
#   570: 'Maruti Suzuki Swift',
#   571: 'Maruti Suzuki Ertiga',
#   572: 'Maruti Suzuki Swift',
#   573: 'Maruti Suzuki Alto',
#   574: 'Hyundai i20 Magna',
#   575: 'Hyundai i10 Magna',
#   576: 'Tata Zest XE',
#   577: 'Mahindra Xylo E8',
#   578: 'Toyota Corolla Altis',
#   579: 'Tata Manza Aqua',
#   580: 'Renault Kwid 1.0',
#   581: 'Tata Venture EX',
#   582: 'Maruti Suzuki Swift',
#   583: 'Skoda Octavia Classic',
#   584: 'Maruti Suzuki Omni',
#   585: 'Chevrolet Beat Diesel',
#   586: 'Tata Sumo Gold',
#   587: 'Hyundai Verna 1.6',
#   588: 'Tata Sumo Gold',
#   589: 'Mahindra Scorpio 2.6',
#   590: 'Maruti Suzuki Zen',
#   591: 'Maruti Suzuki Swift',
#   592: 'Mahindra Scorpio SLX',
#   593: 'Hyundai Grand i10',
#   594: 'Hyundai Elite i20',
#   595: 'Ford Ikon 1.6',
#   596: 'Toyota Innova 2.5',
#   597: 'Nissan Sunny XL',
#   598: 'Chevrolet Beat LT',
#   599: 'Maruti Suzuki Alto',
#   600: 'Maruti Suzuki Swift',
#   601: 'Maruti Suzuki Swift',
#   602: 'Maruti Suzuki Swift',
#   603: 'Toyota Innova 2.0',
#   604: 'Maruti Suzuki Swift',
#   605: 'Hyundai Elite i20',
#   606: 'Mahindra XUV500 W10',
#   607: 'Volkswagen Polo Trendline',
#   608: 'Toyota Etios Liva',
#   609: 'Mahindra TUV300 T4',
#   610: 'Hyundai Elite i20',
#   611: 'Hyundai Santro Xing',
#   612: 'Maruti Suzuki Zen',
#   613: 'Maruti Suzuki Ciaz',
#   614: 'Hyundai Eon Era',
#   615: 'Hyundai Elantra 1.8',
#   616: 'Maruti Suzuki Swift',
#   617: 'Maruti Suzuki Zen',
#   618: 'Hyundai Eon Era',
#   619: 'Hyundai Grand i10',
#   620: 'Hyundai Verna Fluidic',
#   621: 'Ford EcoSport Trend',
#   622: 'Hyundai i20 Magna',
#   623: 'Chevrolet Beat Diesel',
#   624: 'Tata Indica eV2',
#   625: 'Jaguar XF 2.2',
#   626: 'Audi Q5 2.0',
#   627: 'BMW 3 Series',
#   628: 'Maruti Suzuki Swift',
#   629: 'BMW X1 sDrive20d',
#   630: 'Maruti Suzuki S',
#   631: 'Maruti Suzuki Ertiga',
#   632: 'Maruti Suzuki Alto',
#   633: 'Honda City SV',
#   634: 'Volkswagen Vento Comfortline',
#   635: 'Honda City 1.5',
#   636: 'Audi A4 2.0',
#   637: 'Mahindra KUV100',
#   638: 'Tata Zest XE',
#   639: 'Mahindra XUV500 W8',
#   640: 'Maruti Suzuki Swift',
#   641: 'Tata Sumo Gold',
#   642: 'Maruti Suzuki Swift',
#   643: 'Mahindra Scorpio 2.6',
#   644: 'Maruti Suzuki Omni',
#   645: 'Mitsubishi Pajero Sport',
#   646: 'Renault Duster',
#   647: 'Volkswagen Jetta Comfortline',
#   648: 'Maruti Suzuki Ertiga',
#   649: 'Audi A4 2.0',
#   650: 'Volvo S80 Summum',
#   651: 'Toyota Corolla Altis',
#   652: 'Mitsubishi Pajero Sport',
#   653: 'Chevrolet Beat LT',
#   654: 'BMW X1',
#   655: 'Datsun Redi GO',
#   656: 'Mercedes Benz C',
#   657: 'Mahindra Scorpio SLX',
#   658: 'Volkswagen Vento Comfortline',
#   659: 'Tata Indigo CS',
#   660: 'Ford Figo Petrol',
#   661: 'Honda City ZX',
#   662: 'Maruti Suzuki Wagon',
#   663: 'Ford EcoSport Trend',
#   664: 'Maruti Suzuki Swift',
#   665: 'Maruti Suzuki Omni',
#   666: 'Maruti Suzuki Zen',
#   667: 'Renault Duster RxL',
#   668: 'Maruti Suzuki Swift',
#   669: 'Maruti Suzuki Baleno',
#   670: 'Honda WR V',
#   671: 'Tata Indigo CS',
#   672: 'Renault Duster 110',
#   673: 'Mahindra Scorpio LX',
#   674: 'Maruti Suzuki Zen',
#   675: 'Maruti Suzuki Wagon',
#   676: 'Maruti Suzuki SX4',
#   677: 'Audi A3 Cabriolet',
#   678: 'Hyundai Eon D',
#   679: 'Maruti Suzuki Zen',
#   680: 'Mahindra Scorpio SLX',
#   681: 'Hyundai Santro AE',
#   682: 'Maruti Suzuki Swift',
#   683: 'Mahindra Scorpio S4',
#   684: 'Mahindra Xylo D2',
#   685: 'Hyundai Santro',
#   686: 'Chevrolet Beat LT',
#   687: 'Maruti Suzuki Swift',
#   688: 'Mahindra XUV500 W8',
#   689: 'Toyota Fortuner 3.0',
#   690: 'Maruti Suzuki Alto',
#   691: 'Hyundai Getz GLE',
#   692: 'Maruti Suzuki Swift',
#   693: 'Hyundai Creta 1.6',
#   694: 'Hyundai Santro Xing',
#   695: 'Hyundai Santro Xing',
#   696: 'Mahindra Xylo D2',
#   697: 'Hyundai Santro Xing',
#   698: 'Tata Indica V2',
#   699: 'Hyundai i10 Sportz',
#   700: 'Hyundai Grand i10',
#   701: 'Hyundai Santro Xing',
#   702: 'Honda City 1.5',
#   703: 'Nissan Micra XL',
#   704: 'Honda City 1.5',
#   705: 'Maruti Suzuki Alto',
#   706: 'Maruti Suzuki Wagon',
#   707: 'Maruti Suzuki Ertiga',
#   708: 'Tata Indica eV2',
#   709: 'Maruti Suzuki Omni',
#   710: 'Hyundai Eon Era',
#   711: 'Hyundai Eon',
#   712: 'Maruti Suzuki Swift',
#   713: 'Hyundai Verna 1.6',
#   714: 'Chevrolet Tavera LS',
#   715: 'Tata Tiago Revotron',
#   716: 'Tata Tiago Revotorq',
#   717: 'Maruti Suzuki Zen',
#   718: 'Mahindra KUV100 K8',
#   719: 'Ford EcoSport Titanium',
#   720: 'Hindustan Motors Ambassador',
#   721: 'Ford Fusion 1.4',
#   722: 'Hyundai Santro Xing',
#   723: 'Hyundai Santro',
#   724: 'Fiat Linea Emotion',
#   725: 'Ford Ikon 1.3',
#   726: 'Maruti Suzuki Omni',
#   727: 'Tata Indica V2',
#   728: 'Mahindra Scorpio S4',
#   729: 'Hyundai Santro Xing',
#   730: 'Mahindra Xylo D2',
#   731: 'Hyundai Grand i10',
#   732: 'Maruti Suzuki Alto',
#   733: 'Toyota Corolla',
#   734: 'Hyundai Eon Magna',
#   735: 'Tata Sumo Grande',
#   736: 'Maruti Suzuki Swift',
#   737: 'Volkswagen Polo Highline1.2L',
#   738: 'Maruti Suzuki Alto',
#   739: 'Tata Tiago Revotron',
#   740: 'Maruti Suzuki Swift',
#   741: 'Maruti Suzuki Swift',
#   742: 'Tata Indigo eCS',
#   743: 'Chevrolet Beat LS',
#   744: 'Mahindra Xylo E8',
#   745: 'Hyundai Eon D',
#   746: 'Tata Sumo Gold',
#   747: 'Tata Nano',
#   748: 'Hyundai Elite i20',
#   749: 'Hyundai i10 Magna',
#   750: 'Hyundai Creta',
#   751: 'Volkswagen Polo',
#   752: 'Maruti Suzuki Dzire',
#   753: 'Tata Bolt XM',
#   754: 'Maruti Suzuki Alto',
#   755: 'Maruti Suzuki Alto',
#   756: 'Maruti Suzuki Ritz',
#   757: 'Maruti Suzuki Alto',
#   758: 'Maruti Suzuki Dzire',
#   759: 'Hyundai i20 Asta',
#   760: 'Maruti Suzuki Swift',
#   761: 'Tata Indica V2',
#   762: 'Mahindra Scorpio VLX',
#   763: 'Toyota Innova 2.5',
#   764: 'Mahindra Xylo E8',
#   765: 'Hyundai i20 Magna',
#   766: 'Maruti Suzuki Omni',
#   767: 'Mahindra KUV100',
#   768: 'Mahindra KUV100 K8',
#   769: 'Datsun Go Plus',
#   770: 'Ford Endeavor 4x4',
#   771: 'Tata Indica V2',
#   772: 'Hyundai Santro Xing',
#   773: 'Maruti Suzuki Wagon',
#   774: 'Maruti Suzuki Swift',
#   775: 'Maruti Suzuki Alto',
#   776: 'Toyota Innova 2.5',
#   777: 'Maruti Suzuki Alto',
#   778: 'Maruti Suzuki Alto',
#   779: 'Volkswagen Polo Highline1.2L',
#   780: 'Mahindra Logan',
#   781: 'Maruti Suzuki 800',
#   782: 'Mahindra Scorpio',
#   783: 'Chevrolet Sail 1.2',
#   784: 'Hyundai Santro AE',
#   785: 'Maruti Suzuki Wagon',
#   786: 'Hyundai Eon',
#   787: 'Tata Manza',
#   788: 'Toyota Etios G',
#   789: 'Hyundai Getz Prime',
#   790: 'Toyota Qualis',
#   791: 'Hyundai Santro Xing',
#   792: 'Tata Indica eV2',
#   793: 'Honda City 1.5',
#   794: 'Tata Zest XE',
#   795: 'Mahindra Quanto C4',
#   796: 'Tata Indigo eCS',
#   797: 'Maruti Suzuki Swift',
#   798: 'Hyundai Elite i20',
#   799: 'Hyundai i20 Select',
#   800: 'Chevrolet Tavera Neo',
#   801: 'Maruti Suzuki Dzire',
#   802: 'Hyundai Elite i20',
#   803: 'Honda City VX',
#   804: 'Maruti Suzuki Dzire',
#   805: 'Hyundai Getz',
#   806: 'Mercedes Benz C',
#   807: 'Maruti Suzuki Alto',
#   808: 'Maruti Suzuki Swift',
#   809: 'Skoda Fabia',
#   810: 'Maruti Suzuki Ritz',
#   811: 'Tata Indica V2',
#   812: 'Toyota Corolla Altis',
#   813: 'Tata Zest XM',
#   814: 'Mahindra Quanto C8'},
#  'company': {0: 'Hyundai',
#   1: 'Mahindra',
#   2: 'Hyundai',
#   3: 'Ford',
#   4: 'Ford',
#   5: 'Hyundai',
#   6: 'Ford',
#   7: 'Maruti',
#   8: 'Skoda',
#   9: 'Maruti',
#   10: 'Hyundai',
#   11: 'Mahindra',
#   12: 'Hyundai',
#   13: 'Mahindra',
#   14: 'Audi',
#   15: 'Audi',
#   16: 'Mahindra',
#   17: 'Maruti',
#   18: 'Mahindra',
#   19: 'Mahindra',
#   20: 'Maruti',
#   21: 'Hyundai',
#   22: 'Hyundai',
#   23: 'Hyundai',
#   24: 'Maruti',
#   25: 'Maruti',
#   26: 'Maruti',
#   27: 'Mahindra',
#   28: 'Maruti',
#   29: 'Mahindra',
#   30: 'Maruti',
#   31: 'Maruti',
#   32: 'Maruti',
#   33: 'Toyota',
#   34: 'Renault',
#   35: 'Skoda',
#   36: 'Maruti',
#   37: 'Renault',
#   38: 'Renault',
#   39: 'Honda',
#   40: 'Maruti',
#   41: 'Maruti',
#   42: 'Honda',
#   43: 'Honda',
#   44: 'Honda',
#   45: 'Datsun',
#   46: 'Maruti',
#   47: 'Mitsubishi',
#   48: 'Mahindra',
#   49: 'Maruti',
#   50: 'Mahindra',
#   51: 'Maruti',
#   52: 'Maruti',
#   53: 'Maruti',
#   54: 'Mahindra',
#   55: 'Maruti',
#   56: 'Honda',
#   57: 'Maruti',
#   58: 'Ford',
#   59: 'Hyundai',
#   60: 'Tata',
#   61: 'Ford',
#   62: 'Tata',
#   63: 'Mahindra',
#   64: 'Volkswagen',
#   65: 'Skoda',
#   66: 'Maruti',
#   67: 'Chevrolet',
#   68: 'Renault',
#   69: 'Honda',
#   70: 'Mini',
#   71: 'Datsun',
#   72: 'Skoda',
#   73: 'Honda',
#   74: 'Honda',
#   75: 'Renault',
#   76: 'Mini',
#   77: 'Mahindra',
#   78: 'Mahindra',
#   79: 'Mahindra',
#   80: 'Ford',
#   81: 'Honda',
#   82: 'Volkswagen',
#   83: 'Hyundai',
#   84: 'Toyota',
#   85: 'Hyundai',
#   86: 'Toyota',
#   87: 'Honda',
#   88: 'Hyundai',
#   89: 'Skoda',
#   90: 'BMW',
#   91: 'Maruti',
#   92: 'Toyota',
#   93: 'Ford',
#   94: 'Maruti',
#   95: 'Chevrolet',
#   96: 'BMW',
#   97: 'Mahindra',
#   98: 'Hyundai',
#   99: 'Hyundai',
#   100: 'Maruti',
#   101: 'Maruti',
#   102: 'Ford',
#   103: 'Maruti',
#   104: 'Maruti',
#   105: 'Maruti',
#   106: 'Hyundai',
#   107: 'Honda',
#   108: 'Hyundai',
#   109: 'Ford',
#   110: 'Maruti',
#   111: 'Maruti',
#   112: 'Maruti',
#   113: 'Maruti',
#   114: 'Maruti',
#   115: 'Maruti',
#   116: 'Maruti',
#   117: 'Maruti',
#   118: 'Toyota',
#   119: 'Hyundai',
#   120: 'Chevrolet',
#   121: 'Maruti',
#   122: 'Nissan',
#   123: 'Maruti',
#   124: 'Maruti',
#   125: 'Honda',
#   126: 'Maruti',
#   127: 'Chevrolet',
#   128: 'Honda',
#   129: 'Ford',
#   130: 'Hyundai',
#   131: 'Maruti',
#   132: 'Tata',
#   133: 'Hindustan',
#   134: 'Toyota',
#   135: 'Toyota',
#   136: 'Toyota',
#   137: 'Volkswagen',
#   138: 'Volkswagen',
#   139: 'Volkswagen',
#   140: 'Mahindra',
#   141: 'Renault',
#   142: 'Honda',
#   143: 'Nissan',
#   144: 'Hyundai',
#   145: 'Renault',
#   146: 'Renault',
#   147: 'Ford',
#   148: 'Renault',
#   149: 'Mahindra',
#   150: 'Maruti',
#   151: 'Chevrolet',
#   152: 'Datsun',
#   153: 'Maruti',
#   154: 'Fiat',
#   155: 'Maruti',
#   156: 'Toyota',
#   157: 'Hyundai',
#   158: 'Hyundai',
#   159: 'Chevrolet',
#   160: 'Chevrolet',
#   161: 'Chevrolet',
#   162: 'Mahindra',
#   163: 'Tata',
#   164: 'Toyota',
#   165: 'Honda',
#   166: 'Maruti',
#   167: 'Hyundai',
#   168: 'Mahindra',
#   169: 'Mahindra',
#   170: 'Honda',
#   171: 'Ford',
#   172: 'Honda',
#   173: 'Honda',
#   174: 'Maruti',
#   175: 'Honda',
#   176: 'Hyundai',
#   177: 'Tata',
#   178: 'Hyundai',
#   179: 'Mahindra',
#   180: 'Fiat',
#   181: 'Skoda',
#   182: 'Mini',
#   183: 'Hyundai',
#   184: 'Maruti',
#   185: 'Maruti',
#   186: 'Honda',
#   187: 'Hyundai',
#   188: 'Mahindra',
#   189: 'Mahindra',
#   190: 'Toyota',
#   191: 'Maruti',
#   192: 'Maruti',
#   193: 'Tata',
#   194: 'Maruti',
#   195: 'Maruti',
#   196: 'Maruti',
#   197: 'Tata',
#   198: 'Maruti',
#   199: 'Maruti',
#   200: 'Volkswagen',
#   201: 'Renault',
#   202: 'Mahindra',
#   203: 'Hyundai',
#   204: 'Hyundai',
#   205: 'Mahindra',
#   206: 'Mahindra',
#   207: 'Renault',
#   208: 'Mahindra',
#   209: 'Force',
#   210: 'Maruti',
#   211: 'Mahindra',
#   212: 'Maruti',
#   213: 'Mahindra',
#   214: 'Toyota',
#   215: 'Volkswagen',
#   216: 'Honda',
#   217: 'Maruti',
#   218: 'Honda',
#   219: 'Mahindra',
#   220: 'Mitsubishi',
#   221: 'Audi',
#   222: 'Mercedes',
#   223: 'Land',
#   224: 'Renault',
#   225: 'Tata',
#   226: 'Mercedes',
#   227: 'Datsun',
#   228: 'Tata',
#   229: 'Tata',
#   230: 'Honda',
#   231: 'Honda',
#   232: 'Honda',
#   233: 'Honda',
#   234: 'Honda',
#   235: 'Honda',
#   236: 'Audi',
#   237: 'Force',
#   238: 'Mahindra',
#   239: 'Hyundai',
#   240: 'Mini',
#   241: 'Maruti',
#   242: 'Chevrolet',
#   243: 'Honda',
#   244: 'Hyundai',
#   245: 'Tata',
#   246: 'Maruti',
#   247: 'Maruti',
#   248: 'Maruti',
#   249: 'Chevrolet',
#   250: 'Hyundai',
#   251: 'Ford',
#   252: 'Maruti',
#   253: 'Maruti',
#   254: 'Maruti',
#   255: 'Maruti',
#   256: 'Maruti',
#   257: 'Maruti',
#   258: 'Maruti',
#   259: 'Maruti',
#   260: 'Mini',
#   261: 'Nissan',
#   262: 'Renault',
#   263: 'Renault',
#   264: 'Renault',
#   265: 'Maruti',
#   266: 'Renault',
#   267: 'Maruti',
#   268: 'Renault',
#   269: 'Renault',
#   270: 'Renault',
#   271: 'Hyundai',
#   272: 'Maruti',
#   273: 'Chevrolet',
#   274: 'Tata',
#   275: 'Hyundai',
#   276: 'Hyundai',
#   277: 'Chevrolet',
#   278: 'Mahindra',
#   279: 'Fiat',
#   280: 'Chevrolet',
#   281: 'Skoda',
#   282: 'Ford',
#   283: 'Hyundai',
#   284: 'Mahindra',
#   285: 'Mini',
#   286: 'Mini',
#   287: 'Tata',
#   288: 'Mini',
#   289: 'Tata',
#   290: 'Maruti',
#   291: 'Mahindra',
#   292: 'Honda',
#   293: 'Mahindra',
#   294: 'Chevrolet',
#   295: 'Ford',
#   296: 'Maruti',
#   297: 'Honda',
#   298: 'Maruti',
#   299: 'Honda',
#   300: 'Mahindra',
#   301: 'Maruti',
#   302: 'Honda',
#   303: 'Honda',
#   304: 'Toyota',
#   305: 'Honda',
#   306: 'Skoda',
#   307: 'Renault',
#   308: 'Maruti',
#   309: 'Maruti',
#   310: 'Mahindra',
#   311: 'Hyundai',
#   312: 'Maruti',
#   313: 'Maruti',
#   314: 'Mahindra',
#   315: 'Honda',
#   316: 'Mahindra',
#   317: 'Mahindra',
#   318: 'Skoda',
#   319: 'Volkswagen',
#   320: 'Hyundai',
#   321: 'Tata',
#   322: 'Chevrolet',
#   323: 'Renault',
#   324: 'Hyundai',
#   325: 'Audi',
#   326: 'Hyundai',
#   327: 'Mahindra',
#   328: 'Mahindra',
#   329: 'Renault',
#   330: 'Mahindra',
#   331: 'Hyundai',
#   332: 'Hyundai',
#   333: 'Mahindra',
#   334: 'Hyundai',
#   335: 'Hyundai',
#   336: 'Hyundai',
#   337: 'Hyundai',
#   338: 'Hyundai',
#   339: 'Datsun',
#   340: 'Toyota',
#   341: 'Hyundai',
#   342: 'Hyundai',
#   343: 'Maruti',
#   344: 'Toyota',
#   345: 'Hyundai',
#   346: 'Mahindra',
#   347: 'Mahindra',
#   348: 'Honda',
#   349: 'Chevrolet',
#   350: 'Mahindra',
#   351: 'Renault',
#   352: 'Mahindra',
#   353: 'Tata',
#   354: 'Mahindra',
#   355: 'Force',
#   356: 'Skoda',
#   357: 'Tata',
#   358: 'Maruti',
#   359: 'Maruti',
#   360: 'Maruti',
#   361: 'Mahindra',
#   362: 'Hyundai',
#   363: 'Maruti',
#   364: 'Maruti',
#   365: 'Honda',
#   366: 'Mahindra',
#   367: 'Mahindra',
#   368: 'Chevrolet',
#   369: 'Honda',
#   370: 'Hyundai',
#   371: 'Toyota',
#   372: 'Maruti',
#   373: 'Toyota',
#   374: 'Volkswagen',
#   375: 'Maruti',
#   376: 'Hyundai',
#   377: 'Maruti',
#   378: 'Maruti',
#   379: 'Tata',
#   380: 'Volkswagen',
#   381: 'Mercedes',
#   382: 'Maruti',
#   383: 'Honda',
#   384: 'Hyundai',
#   385: 'Maruti',
#   386: 'Hyundai',
#   387: 'Hyundai',
#   388: 'Volkswagen',
#   389: 'Maruti',
#   390: 'Maruti',
#   391: 'Honda',
#   392: 'Hyundai',
#   393: 'Maruti',
#   394: 'Mahindra',
#   395: 'Maruti',
#   396: 'Hyundai',
#   397: 'Mahindra',
#   398: 'Hyundai',
#   399: 'Hyundai',
#   400: 'Renault',
#   401: 'Hyundai',
#   402: 'Honda',
#   403: 'Mahindra',
#   404: 'Chevrolet',
#   405: 'Mahindra',
#   406: 'Maruti',
#   407: 'Nissan',
#   408: 'Maruti',
#   409: 'Ford',
#   410: 'Toyota',
#   411: 'Tata',
#   412: 'Mercedes',
#   413: 'Chevrolet',
#   414: 'Ford',
#   415: 'Tata',
#   416: 'Hyundai',
#   417: 'Volkswagen',
#   418: 'Renault',
#   419: 'Ford',
#   420: 'Honda',
#   421: 'Hyundai',
#   422: 'BMW',
#   423: 'Skoda',
#   424: 'Audi',
#   425: 'Mahindra',
#   426: 'Mahindra',
#   427: 'Ford',
#   428: 'Maruti',
#   429: 'Mahindra',
#   430: 'Tata',
#   431: 'Mahindra',
#   432: 'Mahindra',
#   433: 'Hyundai',
#   434: 'Hyundai',
#   435: 'Honda',
#   436: 'Maruti',
#   437: 'Ford',
#   438: 'Mahindra',
#   439: 'Honda',
#   440: 'Hyundai',
#   441: 'Maruti',
#   442: 'Hyundai',
#   443: 'Mitsubishi',
#   444: 'Hyundai',
#   445: 'Toyota',
#   446: 'Maruti',
#   447: 'Tata',
#   448: 'Mahindra',
#   449: 'Mahindra',
#   450: 'Hyundai',
#   451: 'Honda',
#   452: 'Hyundai',
#   453: 'Maruti',
#   454: 'Tata',
#   455: 'Maruti',
#   456: 'Tata',
#   457: 'Toyota',
#   458: 'Maruti',
#   459: 'Toyota',
#   460: 'Mahindra',
#   461: 'Tata',
#   462: 'Maruti',
#   463: 'Maruti',
#   464: 'Maruti',
#   465: 'Honda',
#   466: 'Maruti',
#   467: 'Maruti',
#   468: 'Hyundai',
#   469: 'Maruti',
#   470: 'Toyota',
#   471: 'Maruti',
#   472: 'Honda',
#   473: 'Tata',
#   474: 'Hyundai',
#   475: 'Maruti',
#   476: 'Maruti',
#   477: 'Maruti',
#   478: 'Honda',
#   479: 'Maruti',
#   480: 'Maruti',
#   481: 'Maruti',
#   482: 'Maruti',
#   483: 'Renault',
#   484: 'Tata',
#   485: 'Jaguar',
#   486: 'Hyundai',
#   487: 'Honda',
#   488: 'Hindustan',
#   489: 'Maruti',
#   490: 'Hyundai',
#   491: 'Hyundai',
#   492: 'Maruti',
#   493: 'Maruti',
#   494: 'Honda',
#   495: 'Maruti',
#   496: 'Maruti',
#   497: 'Maruti',
#   498: 'Hyundai',
#   499: 'Mahindra',
#   500: 'Maruti',
#   501: 'Mitsubishi',
#   502: 'Maruti',
#   503: 'Maruti',
#   504: 'Hyundai',
#   505: 'Hyundai',
#   506: 'Ford',
#   507: 'Maruti',
#   508: 'Hyundai',
#   509: 'Maruti',
#   510: 'Maruti',
#   511: 'Audi',
#   512: 'Maruti',
#   513: 'Maruti',
#   514: 'Maruti',
#   515: 'Maruti',
#   516: 'Maruti',
#   517: 'Hyundai',
#   518: 'Maruti',
#   519: 'Hyundai',
#   520: 'Hyundai',
#   521: 'Hyundai',
#   522: 'Chevrolet',
#   523: 'Ford',
#   524: 'Maruti',
#   525: 'Hyundai',
#   526: 'Tata',
#   527: 'BMW',
#   528: 'Hyundai',
#   529: 'Honda',
#   530: 'Tata',
#   531: 'Chevrolet',
#   532: 'Hyundai',
#   533: 'Maruti',
#   534: 'Mahindra',
#   535: 'Maruti',
#   536: 'Hyundai',
#   537: 'Force',
#   538: 'Maruti',
#   539: 'Chevrolet',
#   540: 'Hyundai',
#   541: 'Toyota',
#   542: 'Renault',
#   543: 'Chevrolet',
#   544: 'Maruti',
#   545: 'BMW',
#   546: 'Toyota',
#   547: 'Mahindra',
#   548: 'Chevrolet',
#   549: 'Chevrolet',
#   550: 'Jeep',
#   551: 'Maruti',
#   552: 'Hyundai',
#   553: 'Maruti',
#   554: 'Maruti',
#   555: 'Tata',
#   556: 'Mahindra',
#   557: 'Tata',
#   558: 'Hyundai',
#   559: 'Tata',
#   560: 'Tata',
#   561: 'Tata',
#   562: 'Tata',
#   563: 'Hyundai',
#   564: 'Hyundai',
#   565: 'Renault',
#   566: 'Maruti',
#   567: 'Tata',
#   568: 'Renault',
#   569: 'Maruti',
#   570: 'Maruti',
#   571: 'Maruti',
#   572: 'Maruti',
#   573: 'Maruti',
#   574: 'Hyundai',
#   575: 'Hyundai',
#   576: 'Tata',
#   577: 'Mahindra',
#   578: 'Toyota',
#   579: 'Tata',
#   580: 'Renault',
#   581: 'Tata',
#   582: 'Maruti',
#   583: 'Skoda',
#   584: 'Maruti',
#   585: 'Chevrolet',
#   586: 'Tata',
#   587: 'Hyundai',
#   588: 'Tata',
#   589: 'Mahindra',
#   590: 'Maruti',
#   591: 'Maruti',
#   592: 'Mahindra',
#   593: 'Hyundai',
#   594: 'Hyundai',
#   595: 'Ford',
#   596: 'Toyota',
#   597: 'Nissan',
#   598: 'Chevrolet',
#   599: 'Maruti',
#   600: 'Maruti',
#   601: 'Maruti',
#   602: 'Maruti',
#   603: 'Toyota',
#   604: 'Maruti',
#   605: 'Hyundai',
#   606: 'Mahindra',
#   607: 'Volkswagen',
#   608: 'Toyota',
#   609: 'Mahindra',
#   610: 'Hyundai',
#   611: 'Hyundai',
#   612: 'Maruti',
#   613: 'Maruti',
#   614: 'Hyundai',
#   615: 'Hyundai',
#   616: 'Maruti',
#   617: 'Maruti',
#   618: 'Hyundai',
#   619: 'Hyundai',
#   620: 'Hyundai',
#   621: 'Ford',
#   622: 'Hyundai',
#   623: 'Chevrolet',
#   624: 'Tata',
#   625: 'Jaguar',
#   626: 'Audi',
#   627: 'BMW',
#   628: 'Maruti',
#   629: 'BMW',
#   630: 'Maruti',
#   631: 'Maruti',
#   632: 'Maruti',
#   633: 'Honda',
#   634: 'Volkswagen',
#   635: 'Honda',
#   636: 'Audi',
#   637: 'Mahindra',
#   638: 'Tata',
#   639: 'Mahindra',
#   640: 'Maruti',
#   641: 'Tata',
#   642: 'Maruti',
#   643: 'Mahindra',
#   644: 'Maruti',
#   645: 'Mitsubishi',
#   646: 'Renault',
#   647: 'Volkswagen',
#   648: 'Maruti',
#   649: 'Audi',
#   650: 'Volvo',
#   651: 'Toyota',
#   652: 'Mitsubishi',
#   653: 'Chevrolet',
#   654: 'BMW',
#   655: 'Datsun',
#   656: 'Mercedes',
#   657: 'Mahindra',
#   658: 'Volkswagen',
#   659: 'Tata',
#   660: 'Ford',
#   661: 'Honda',
#   662: 'Maruti',
#   663: 'Ford',
#   664: 'Maruti',
#   665: 'Maruti',
#   666: 'Maruti',
#   667: 'Renault',
#   668: 'Maruti',
#   669: 'Maruti',
#   670: 'Honda',
#   671: 'Tata',
#   672: 'Renault',
#   673: 'Mahindra',
#   674: 'Maruti',
#   675: 'Maruti',
#   676: 'Maruti',
#   677: 'Audi',
#   678: 'Hyundai',
#   679: 'Maruti',
#   680: 'Mahindra',
#   681: 'Hyundai',
#   682: 'Maruti',
#   683: 'Mahindra',
#   684: 'Mahindra',
#   685: 'Hyundai',
#   686: 'Chevrolet',
#   687: 'Maruti',
#   688: 'Mahindra',
#   689: 'Toyota',
#   690: 'Maruti',
#   691: 'Hyundai',
#   692: 'Maruti',
#   693: 'Hyundai',
#   694: 'Hyundai',
#   695: 'Hyundai',
#   696: 'Mahindra',
#   697: 'Hyundai',
#   698: 'Tata',
#   699: 'Hyundai',
#   700: 'Hyundai',
#   701: 'Hyundai',
#   702: 'Honda',
#   703: 'Nissan',
#   704: 'Honda',
#   705: 'Maruti',
#   706: 'Maruti',
#   707: 'Maruti',
#   708: 'Tata',
#   709: 'Maruti',
#   710: 'Hyundai',
#   711: 'Hyundai',
#   712: 'Maruti',
#   713: 'Hyundai',
#   714: 'Chevrolet',
#   715: 'Tata',
#   716: 'Tata',
#   717: 'Maruti',
#   718: 'Mahindra',
#   719: 'Ford',
#   720: 'Hindustan',
#   721: 'Ford',
#   722: 'Hyundai',
#   723: 'Hyundai',
#   724: 'Fiat',
#   725: 'Ford',
#   726: 'Maruti',
#   727: 'Tata',
#   728: 'Mahindra',
#   729: 'Hyundai',
#   730: 'Mahindra',
#   731: 'Hyundai',
#   732: 'Maruti',
#   733: 'Toyota',
#   734: 'Hyundai',
#   735: 'Tata',
#   736: 'Maruti',
#   737: 'Volkswagen',
#   738: 'Maruti',
#   739: 'Tata',
#   740: 'Maruti',
#   741: 'Maruti',
#   742: 'Tata',
#   743: 'Chevrolet',
#   744: 'Mahindra',
#   745: 'Hyundai',
#   746: 'Tata',
#   747: 'Tata',
#   748: 'Hyundai',
#   749: 'Hyundai',
#   750: 'Hyundai',
#   751: 'Volkswagen',
#   752: 'Maruti',
#   753: 'Tata',
#   754: 'Maruti',
#   755: 'Maruti',
#   756: 'Maruti',
#   757: 'Maruti',
#   758: 'Maruti',
#   759: 'Hyundai',
#   760: 'Maruti',
#   761: 'Tata',
#   762: 'Mahindra',
#   763: 'Toyota',
#   764: 'Mahindra',
#   765: 'Hyundai',
#   766: 'Maruti',
#   767: 'Mahindra',
#   768: 'Mahindra',
#   769: 'Datsun',
#   770: 'Ford',
#   771: 'Tata',
#   772: 'Hyundai',
#   773: 'Maruti',
#   774: 'Maruti',
#   775: 'Maruti',
#   776: 'Toyota',
#   777: 'Maruti',
#   778: 'Maruti',
#   779: 'Volkswagen',
#   780: 'Mahindra',
#   781: 'Maruti',
#   782: 'Mahindra',
#   783: 'Chevrolet',
#   784: 'Hyundai',
#   785: 'Maruti',
#   786: 'Hyundai',
#   787: 'Tata',
#   788: 'Toyota',
#   789: 'Hyundai',
#   790: 'Toyota',
#   791: 'Hyundai',
#   792: 'Tata',
#   793: 'Honda',
#   794: 'Tata',
#   795: 'Mahindra',
#   796: 'Tata',
#   797: 'Maruti',
#   798: 'Hyundai',
#   799: 'Hyundai',
#   800: 'Chevrolet',
#   801: 'Maruti',
#   802: 'Hyundai',
#   803: 'Honda',
#   804: 'Maruti',
#   805: 'Hyundai',
#   806: 'Mercedes',
#   807: 'Maruti',
#   808: 'Maruti',
#   809: 'Skoda',
#   810: 'Maruti',
#   811: 'Tata',
#   812: 'Toyota',
#   813: 'Tata',
#   814: 'Mahindra'},
#  'year': {0: 2007,
#   1: 2006,
#   2: 2014,
#   3: 2014,
#   4: 2012,
#   5: 2013,
#   6: 2016,
#   7: 2015,
#   8: 2010,
#   9: 2015,
#   10: 2014,
#   11: 2015,
#   12: 2007,
#   13: 2006,
#   14: 2017,
#   15: 2014,
#   16: 2016,
#   17: 2014,
#   18: 2016,
#   19: 2016,
#   20: 2015,
#   21: 2012,
#   22: 2012,
#   23: 2012,
#   24: 2017,
#   25: 2016,
#   26: 2008,
#   27: 2017,
#   28: 2014,
#   29: 2015,
#   30: 2017,
#   31: 2013,
#   32: 2013,
#   33: 2012,
#   34: 2018,
#   35: 2012,
#   36: 2017,
#   37: 2012,
#   38: 2013,
#   39: 2011,
#   40: 2015,
#   41: 2013,
#   42: 2013,
#   43: 2015,
#   44: 2015,
#   45: 2017,
#   46: 2010,
#   47: 2015,
#   48: 2017,
#   49: 2014,
#   50: 2015,
#   51: 2017,
#   52: 2013,
#   53: 2013,
#   54: 2015,
#   55: 2017,
#   56: 2017,
#   57: 2013,
#   58: 2012,
#   59: 2013,
#   60: 2017,
#   61: 2016,
#   62: 2017,
#   63: 2012,
#   64: 2014,
#   65: 2010,
#   66: 2015,
#   67: 2010,
#   68: 2012,
#   69: 2015,
#   70: 2013,
#   71: 2017,
#   72: 2011,
#   73: 2015,
#   74: 2015,
#   75: 2014,
#   76: 2013,
#   77: 2015,
#   78: 2014,
#   79: 2013,
#   80: 2017,
#   81: 2012,
#   82: 2019,
#   83: 2009,
#   84: 2010,
#   85: 2008,
#   86: 2009,
#   87: 2005,
#   88: 2014,
#   89: 2011,
#   90: 2011,
#   91: 2011,
#   92: 2013,
#   93: 2012,
#   94: 2014,
#   95: 2012,
#   96: 2009,
#   97: 2013,
#   98: 2014,
#   99: 2015,
#   100: 2013,
#   101: 2016,
#   102: 2014,
#   103: 2016,
#   104: 2013,
#   105: 2012,
#   106: 2014,
#   107: 2014,
#   108: 2012,
#   109: 2014,
#   110: 2015,
#   111: 2014,
#   112: 2007,
#   113: 2014,
#   114: 2009,
#   115: 2013,
#   116: 2013,
#   117: 2015,
#   118: 2014,
#   119: 2011,
#   120: 2012,
#   121: 2017,
#   122: 2011,
#   123: 2007,
#   124: 2018,
#   125: 2013,
#   126: 2015,
#   127: 2015,
#   128: 2010,
#   129: 2016,
#   130: 2009,
#   131: 2013,
#   132: 2006,
#   133: 2000,
#   134: 2010,
#   135: 2012,
#   136: 2012,
#   137: 2014,
#   138: 2015,
#   139: 2014,
#   140: 2015,
#   141: 2014,
#   142: 2015,
#   143: 2012,
#   144: 2018,
#   145: 2016,
#   146: 2013,
#   147: 2017,
#   148: 2014,
#   149: 2011,
#   150: 2018,
#   151: 2010,
#   152: 2016,
#   153: 2010,
#   154: 2012,
#   155: 2010,
#   156: 2013,
#   157: 2014,
#   158: 2010,
#   159: 2011,
#   160: 2011,
#   161: 2012,
#   162: 2014,
#   163: 2011,
#   164: 2015,
#   165: 2014,
#   166: 2011,
#   167: 2013,
#   168: 2015,
#   169: 2014,
#   170: 2012,
#   171: 2011,
#   172: 2013,
#   173: 2015,
#   174: 2012,
#   175: 2014,
#   176: 2009,
#   177: 2016,
#   178: 2015,
#   179: 2013,
#   180: 2008,
#   181: 2011,
#   182: 2013,
#   183: 2005,
#   184: 2016,
#   185: 2000,
#   186: 2015,
#   187: 2017,
#   188: 2007,
#   189: 2012,
#   190: 2006,
#   191: 2011,
#   192: 2011,
#   193: 2013,
#   194: 2013,
#   195: 2009,
#   196: 2006,
#   197: 2012,
#   198: 2010,
#   199: 2010,
#   200: 2009,
#   201: 2015,
#   202: 2013,
#   203: 2014,
#   204: 2015,
#   205: 2012,
#   206: 2019,
#   207: 2012,
#   208: 2013,
#   209: 2015,
#   210: 2012,
#   211: 2019,
#   212: 2015,
#   213: 2018,
#   214: 2011,
#   215: 2015,
#   216: 2008,
#   217: 2006,
#   218: 2016,
#   219: 2016,
#   220: 2015,
#   221: 2009,
#   222: 2015,
#   223: 2015,
#   224: 2017,
#   225: 2014,
#   226: 2014,
#   227: 2016,
#   228: 2016,
#   229: 2016,
#   230: 2016,
#   231: 2014,
#   232: 2013,
#   233: 2012,
#   234: 2015,
#   235: 2015,
#   236: 2009,
#   237: 2015,
#   238: 2015,
#   239: 2015,
#   240: 2013,
#   241: 2017,
#   242: 2013,
#   243: 2013,
#   244: 2012,
#   245: 2013,
#   246: 2003,
#   247: 2006,
#   248: 2015,
#   249: 2013,
#   250: 2012,
#   251: 2014,
#   252: 2015,
#   253: 2014,
#   254: 2007,
#   255: 2014,
#   256: 2009,
#   257: 2013,
#   258: 2010,
#   259: 2015,
#   260: 2013,
#   261: 2015,
#   262: 2013,
#   263: 2014,
#   264: 2015,
#   265: 2013,
#   266: 2018,
#   267: 2003,
#   268: 2018,
#   269: 2018,
#   270: 2014,
#   271: 2014,
#   272: 2011,
#   273: 2010,
#   274: 2016,
#   275: 2000,
#   276: 2015,
#   277: 2010,
#   278: 2013,
#   279: 2008,
#   280: 2015,
#   281: 2011,
#   282: 2016,
#   283: 2006,
#   284: 2016,
#   285: 2013,
#   286: 2013,
#   287: 2008,
#   288: 2013,
#   289: 2009,
#   290: 2019,
#   291: 2004,
#   292: 2009,
#   293: 2015,
#   294: 2013,
#   295: 2014,
#   296: 2015,
#   297: 2014,
#   298: 2012,
#   299: 2011,
#   300: 2007,
#   301: 2014,
#   302: 2015,
#   303: 2014,
#   304: 2009,
#   305: 2014,
#   306: 2012,
#   307: 2015,
#   308: 2018,
#   309: 2015,
#   310: 2014,
#   311: 2012,
#   312: 2016,
#   313: 2016,
#   314: 2015,
#   315: 2014,
#   316: 2013,
#   317: 2013,
#   318: 2013,
#   319: 2010,
#   320: 2016,
#   321: 2012,
#   322: 2013,
#   323: 2012,
#   324: 2013,
#   325: 2012,
#   326: 2013,
#   327: 2013,
#   328: 2016,
#   329: 2015,
#   330: 2013,
#   331: 2014,
#   332: 2015,
#   333: 2012,
#   334: 2017,
#   335: 2014,
#   336: 2014,
#   337: 2012,
#   338: 2015,
#   339: 2017,
#   340: 2011,
#   341: 2010,
#   342: 2014,
#   343: 2013,
#   344: 2011,
#   345: 2012,
#   346: 2018,
#   347: 2015,
#   348: 2010,
#   349: 2009,
#   350: 2019,
#   351: 2012,
#   352: 2016,
#   353: 2014,
#   354: 2013,
#   355: 2015,
#   356: 2013,
#   357: 2011,
#   358: 2015,
#   359: 2012,
#   360: 2003,
#   361: 2019,
#   362: 2011,
#   363: 2015,
#   364: 2016,
#   365: 2008,
#   366: 2018,
#   367: 2006,
#   368: 2017,
#   369: 2010,
#   370: 2014,
#   371: 2012,
#   372: 1995,
#   373: 2011,
#   374: 2015,
#   375: 2014,
#   376: 2015,
#   377: 2012,
#   378: 2004,
#   379: 2016,
#   380: 2011,
#   381: 2002,
#   382: 2013,
#   383: 2000,
#   384: 2006,
#   385: 2001,
#   386: 2017,
#   387: 2018,
#   388: 2011,
#   389: 2017,
#   390: 2011,
#   391: 2009,
#   392: 2017,
#   393: 2001,
#   394: 2012,
#   395: 2014,
#   396: 2016,
#   397: 2012,
#   398: 2016,
#   399: 2013,
#   400: 2015,
#   401: 2014,
#   402: 2012,
#   403: 2017,
#   404: 2010,
#   405: 2018,
#   406: 2015,
#   407: 2019,
#   408: 2015,
#   409: 2001,
#   410: 2010,
#   411: 2010,
#   412: 2013,
#   413: 2016,
#   414: 2013,
#   415: 2016,
#   416: 2010,
#   417: 2015,
#   418: 2015,
#   419: 2014,
#   420: 2016,
#   421: 2017,
#   422: 2011,
#   423: 2011,
#   424: 2013,
#   425: 2012,
#   426: 2015,
#   427: 2012,
#   428: 2018,
#   429: 2009,
#   430: 2010,
#   431: 2016,
#   432: 2016,
#   433: 2015,
#   434: 2015,
#   435: 2017,
#   436: 2016,
#   437: 2011,
#   438: 2015,
#   439: 2017,
#   440: 2015,
#   441: 2004,
#   442: 2018,
#   443: 2015,
#   444: 2008,
#   445: 2003,
#   446: 2011,
#   447: 2015,
#   448: 2015,
#   449: 2015,
#   450: 2016,
#   451: 2015,
#   452: 2009,
#   453: 2016,
#   454: 2018,
#   455: 2017,
#   456: 2014,
#   457: 2010,
#   458: 2013,
#   459: 2015,
#   460: 2013,
#   461: 2019,
#   462: 2001,
#   463: 2015,
#   464: 2004,
#   465: 2014,
#   466: 2016,
#   467: 2017,
#   468: 2016,
#   469: 2007,
#   470: 2015,
#   471: 2014,
#   472: 2013,
#   473: 2005,
#   474: 2003,
#   475: 2010,
#   476: 2014,
#   477: 2007,
#   478: 2017,
#   479: 2003,
#   480: 2008,
#   481: 2016,
#   482: 2010,
#   483: 2019,
#   484: 2010,
#   485: 2016,
#   486: 2014,
#   487: 2014,
#   488: 2002,
#   489: 2010,
#   490: 2017,
#   491: 2016,
#   492: 2015,
#   493: 2017,
#   494: 2014,
#   495: 2013,
#   496: 2016,
#   497: 2015,
#   498: 2016,
#   499: 2013,
#   500: 2012,
#   501: 2006,
#   502: 2001,
#   503: 2015,
#   504: 2015,
#   505: 2018,
#   506: 2009,
#   507: 2010,
#   508: 2012,
#   509: 2006,
#   510: 2007,
#   511: 2012,
#   512: 2003,
#   513: 2009,
#   514: 2009,
#   515: 2010,
#   516: 2016,
#   517: 2019,
#   518: 2009,
#   519: 2009,
#   520: 2000,
#   521: 2009,
#   522: 2012,
#   523: 2017,
#   524: 2013,
#   525: 2013,
#   526: 2005,
#   527: 2011,
#   528: 2010,
#   529: 2009,
#   530: 2013,
#   531: 2014,
#   532: 2015,
#   533: 2011,
#   534: 2018,
#   535: 2014,
#   536: 2006,
#   537: 2013,
#   538: 2019,
#   539: 2011,
#   540: 2009,
#   541: 2012,
#   542: 2013,
#   543: 2014,
#   544: 2017,
#   545: 2009,
#   546: 2014,
#   547: 2004,
#   548: 2016,
#   549: 2011,
#   550: 2015,
#   551: 2013,
#   552: 2010,
#   553: 2012,
#   554: 2018,
#   555: 2017,
#   556: 2013,
#   557: 2016,
#   558: 2011,
#   559: 2014,
#   560: 2016,
#   561: 2016,
#   562: 2004,
#   563: 2015,
#   564: 2013,
#   565: 2015,
#   566: 2009,
#   567: 2010,
#   568: 2013,
#   569: 2010,
#   570: 2006,
#   571: 2012,
#   572: 2014,
#   573: 2017,
#   574: 2010,
#   575: 2009,
#   576: 2017,
#   577: 2009,
#   578: 2010,
#   579: 2014,
#   580: 2018,
#   581: 2013,
#   582: 2014,
#   583: 2006,
#   584: 2012,
#   585: 2011,
#   586: 2012,
#   587: 2018,
#   588: 2012,
#   589: 2007,
#   590: 2002,
#   591: 2011,
#   592: 2008,
#   593: 2014,
#   594: 2017,
#   595: 2003,
#   596: 2011,
#   597: 2011,
#   598: 2012,
#   599: 2017,
#   600: 2012,
#   601: 2012,
#   602: 2012,
#   603: 2012,
#   604: 2010,
#   605: 2015,
#   606: 2016,
#   607: 2015,
#   608: 2012,
#   609: 2016,
#   610: 2015,
#   611: 2014,
#   612: 2003,
#   613: 2016,
#   614: 2013,
#   615: 2012,
#   616: 2010,
#   617: 2008,
#   618: 2012,
#   619: 2016,
#   620: 2011,
#   621: 2014,
#   622: 2011,
#   623: 2016,
#   624: 2015,
#   625: 2013,
#   626: 2014,
#   627: 2011,
#   628: 2015,
#   629: 2012,
#   630: 2016,
#   631: 2013,
#   632: 2016,
#   633: 2014,
#   634: 2011,
#   635: 2005,
#   636: 2016,
#   637: 2017,
#   638: 2018,
#   639: 2015,
#   640: 2017,
#   641: 2014,
#   642: 2009,
#   643: 2004,
#   644: 2009,
#   645: 2015,
#   646: 2014,
#   647: 2009,
#   648: 2012,
#   649: 2013,
#   650: 2015,
#   651: 2014,
#   652: 2015,
#   653: 2012,
#   654: 2011,
#   655: 2018,
#   656: 2009,
#   657: 2004,
#   658: 2011,
#   659: 2017,
#   660: 2019,
#   661: 2006,
#   662: 2008,
#   663: 2014,
#   664: 2016,
#   665: 2009,
#   666: 2004,
#   667: 2015,
#   668: 2014,
#   669: 2018,
#   670: 2009,
#   671: 2016,
#   672: 2013,
#   673: 2009,
#   674: 2004,
#   675: 2014,
#   676: 2016,
#   677: 2015,
#   678: 2018,
#   679: 2009,
#   680: 2008,
#   681: 2011,
#   682: 2009,
#   683: 2015,
#   684: 2011,
#   685: 2003,
#   686: 2015,
#   687: 2015,
#   688: 2015,
#   689: 2013,
#   690: 2013,
#   691: 2007,
#   692: 2014,
#   693: 2019,
#   694: 2007,
#   695: 2009,
#   696: 2011,
#   697: 2007,
#   698: 2009,
#   699: 2011,
#   700: 2017,
#   701: 2007,
#   702: 2005,
#   703: 2017,
#   704: 2005,
#   705: 2015,
#   706: 2004,
#   707: 2012,
#   708: 2012,
#   709: 2013,
#   710: 2014,
#   711: 2014,
#   712: 2015,
#   713: 2012,
#   714: 2005,
#   715: 2018,
#   716: 2019,
#   717: 2006,
#   718: 2018,
#   719: 2014,
#   720: 1995,
#   721: 2007,
#   722: 2007,
#   723: 2002,
#   724: 2009,
#   725: 2008,
#   726: 2017,
#   727: 2012,
#   728: 2015,
#   729: 2007,
#   730: 2009,
#   731: 2014,
#   732: 2015,
#   733: 2006,
#   734: 2017,
#   735: 2010,
#   736: 2011,
#   737: 2013,
#   738: 2003,
#   739: 2017,
#   740: 2009,
#   741: 2009,
#   742: 2016,
#   743: 2014,
#   744: 2011,
#   745: 2013,
#   746: 2013,
#   747: 2013,
#   748: 2017,
#   749: 2009,
#   750: 2016,
#   751: 2013,
#   752: 2014,
#   753: 2015,
#   754: 2005,
#   755: 2005,
#   756: 2010,
#   757: 2017,
#   758: 2009,
#   759: 2014,
#   760: 2008,
#   761: 2005,
#   762: 2014,
#   763: 2012,
#   764: 2010,
#   765: 2011,
#   766: 2000,
#   767: 2016,
#   768: 2019,
#   769: 2016,
#   770: 2019,
#   771: 2005,
#   772: 2006,
#   773: 2016,
#   774: 2008,
#   775: 2019,
#   776: 2011,
#   777: 2016,
#   778: 2019,
#   779: 2017,
#   780: 2009,
#   781: 2000,
#   782: 2011,
#   783: 2013,
#   784: 2003,
#   785: 2006,
#   786: 2018,
#   787: 2015,
#   788: 2013,
#   789: 2009,
#   790: 2003,
#   791: 2004,
#   792: 2016,
#   793: 2009,
#   794: 2017,
#   795: 2013,
#   796: 2016,
#   797: 2016,
#   798: 2011,
#   799: 2011,
#   800: 2007,
#   801: 2016,
#   802: 2018,
#   803: 2016,
#   804: 2016,
#   805: 2006,
#   806: 2006,
#   807: 2005,
#   808: 2009,
#   809: 2009,
#   810: 2011,
#   811: 2009,
#   812: 2009,
#   813: 2018,
#   814: 2013},
#  'Price': {0: 80000,
#   1: 425000,
#   2: 325000,
#   3: 575000,
#   4: 175000,
#   5: 190000,
#   6: 830000,
#   7: 250000,
#   8: 182000,
#   9: 315000,
#   10: 415000,
#   11: 320000,
#   12: 80000,
#   13: 425000,
#   14: 1000000,
#   15: 500000,
#   16: 350000,
#   17: 160000,
#   18: 350000,
#   19: 310000,
#   20: 75000,
#   21: 100000,
#   22: 100000,
#   23: 100000,
#   24: 190000,
#   25: 290000,
#   26: 95000,
#   27: 180000,
#   28: 385000,
#   29: 250000,
#   30: 180000,
#   31: 105000,
#   32: 105000,
#   33: 650000,
#   34: 689999,
#   35: 448000,
#   36: 549000,
#   37: 501000,
#   38: 489999,
#   39: 280000,
#   40: 250000,
#   41: 349999,
#   42: 284999,
#   43: 345000,
#   44: 499999,
#   45: 235000,
#   46: 249999,
#   47: 1475000,
#   48: 180000,
#   49: 385000,
#   50: 250000,
#   51: 180000,
#   52: 105000,
#   53: 105000,
# ...
#   654: 34000,
#   655: 7000,
#   656: 76000,
#   657: 60000,
#   658: 95000,
#   659: 50000,
#   660: 0,
#   661: 50000,
#   662: 68000,
#   663: 16000,
#   664: 51000,
#   665: 56000,
#   666: 100000,
#   667: 36000,
#   668: 11523,
#   669: 1000,
#   670: 60000,
#   671: 85000,
#   672: 38600,
#   673: 95500,
#   674: 56000,
#   675: 37458,
#   676: 85960,
#   677: 12516,
#   678: 35000,
#   679: 0,
#   680: 80000,
#   681: 45000,
#   682: 51000,
#   683: 30000,
#   684: 48000,
#   685: 51000,
#   686: 90000,
#   687: 43000,
#   688: 53000,
#   689: 97000,
#   690: 20000,
#   691: 55000,
#   692: 120000,
#   693: 0,
#   694: 46000,
#   695: 43200,
#   696: 56000,
#   697: 42000,
#   698: 30600,
#   699: 38000,
#   700: 2550,
#   701: 47000,
#   702: 41000,
#   703: 62500,
#   704: 68000,
#   705: 50000,
#   706: 69000,
#   707: 48000,
#   708: 55000,
#   709: 25000,
#   710: 28400,
#   711: 28000,
#   712: 42000,
#   713: 29000,
#   714: 68485,
#   715: 3500,
#   716: 0,
#   717: 32000,
#   718: 8000,
#   719: 34000,
#   720: 37000,
#   721: 85455,
#   722: 46000,
#   723: 47000,
#   724: 64000,
#   725: 46000,
#   726: 8000,
#   727: 64000,
#   728: 63000,
#   729: 65000,
#   730: 62000,
#   731: 41000,
#   732: 14000,
#   733: 40000,
#   734: 1600,
#   735: 90000,
#   736: 58000,
#   737: 27000,
#   738: 60000,
#   739: 31000,
#   740: 90000,
#   741: 90000,
#   742: 150000,
#   743: 31000,
#   744: 43000,
#   745: 20000,
#   746: 100000,
#   747: 7000,
#   748: 31000,
#   749: 33000,
#   750: 60000,
#   751: 48000,
#   752: 33000,
#   753: 15000,
#   754: 47000,
#   755: 40000,
#   756: 38000,
#   757: 12500,
#   758: 42000,
#   759: 31000,
#   760: 60000,
#   761: 80000,
#   762: 77000,
#   763: 75000,
#   764: 40000,
#   765: 47000,
#   766: 60000,
#   767: 26500,
#   768: 2875,
#   769: 13900,
#   770: 9000,
#   771: 80000,
#   772: 60000,
#   773: 20000,
#   774: 58000,
#   775: 1500,
#   776: 75000,
#   777: 2450,
#   778: 1625,
#   779: 45000,
#   780: 65000,
#   781: 33400,
#   782: 60123,
#   783: 28000,
#   784: 70000,
#   785: 7000,
#   786: 25000,
#   787: 100000,
#   788: 42000,
#   789: 20000,
#   790: 100000,
#   791: 137495,
#   792: 91200,
#   793: 55000,
#   794: 120000,
#   795: 63000,
#   796: 104000,
#   797: 146000,
#   798: 40000,
#   799: 40000,
#   800: 100800,
#   801: 150000,
#   802: 2100,
#   803: 95000,
#   804: 2500,
#   805: 80000,
#   806: 15000,
#   807: 65000,
#   808: 51000,
#   809: 45000,
#   810: 50000,
#   811: 30000,
#   812: 132000,
#   813: 27000,
#   814: 40000},
#  'fuel_type': {0: 'Petrol',
#   1: 'Diesel',
#   2: 'Petrol',
#   3: 'Diesel',
#   4: 'Diesel',
#   5: 'Petrol',
#   6: 'Diesel',
#   7: 'Petrol',
#   8: 'Petrol',
#   9: 'Petrol',
#   10: 'Petrol',
#   11: 'Diesel',
#   12: 'Petrol',
#   13: 'Diesel',
#   14: 'Petrol',
#   15: 'Diesel',
#   16: 'Diesel',
#   17: 'Petrol',
#   18: 'Diesel',
#   19: 'Diesel',
#   20: 'Petrol',
#   21: 'Petrol',
#   22: 'Petrol',
#   23: 'Petrol',
#   24: 'Petrol',
#   25: 'Diesel',
#   26: 'Petrol',
#   27: 'Diesel',
#   28: 'Diesel',
#   29: 'Diesel',
#   30: 'Petrol',
#   31: 'Petrol',
#   32: 'Petrol',
#   33: 'Diesel',
#   34: 'Diesel',
#   35: 'Diesel',
#   36: 'Diesel',
#   37: 'Diesel',
#   38: 'Diesel',
#   39: 'Petrol',
#   40: 'Petrol',
#   41: 'Diesel',
#   42: 'Diesel',
#   43: 'Diesel',
#   44: 'Petrol',
#   45: 'Petrol',
#   46: 'Petrol',
#   47: 'Diesel',
#   48: 'Diesel',
#   49: 'Diesel',
#   50: 'Diesel',
#   51: 'Petrol',
#   52: 'Petrol',
#   53: 'Petrol',
#   54: 'Diesel',
#   55: 'Petrol',
#   56: 'Diesel',
#   57: 'Petrol',
#   58: 'Diesel',
#   59: 'Petrol',
#   60: 'Diesel',
#   61: 'Diesel',
#   62: 'Diesel',
#   63: 'Diesel',
#   64: 'Petrol',
#   65: 'Petrol',
#   66: 'Petrol',
#   67: 'Petrol',
#   68: 'Diesel',
#   69: 'Petrol',
#   70: 'Petrol',
#   71: 'Petrol',
#   72: 'Diesel',
#   73: 'Petrol',
#   74: 'Petrol',
#   75: 'Diesel',
#   76: 'Petrol',
#   77: 'Diesel',
#   78: 'Diesel',
#   79: 'Diesel',
#   80: 'Petrol',
#   81: 'Petrol',
#   82: 'Diesel',
#   83: 'Petrol',
#   84: 'Diesel',
#   85: 'Petrol',
#   86: 'Petrol',
#   87: 'Petrol',
#   88: 'Petrol',
#   89: 'Diesel',
#   90: 'Petrol',
#   91: 'Petrol',
#   92: 'Diesel',
#   93: 'Diesel',
#   94: 'Petrol',
#   95: 'Diesel',
#   96: 'Petrol',
#   97: 'Diesel',
#   98: 'Petrol',
#   99: 'Diesel',
#   100: 'Petrol',
#   101: 'Petrol',
#   102: 'Diesel',
#   103: 'Petrol',
#   104: 'Diesel',
#   105: 'Petrol',
#   106: 'Diesel',
#   107: 'Petrol',
#   108: 'Diesel',
#   109: 'Diesel',
#   110: 'Petrol',
#   111: 'Petrol',
#   112: 'Petrol',
#   113: 'Petrol',
#   114: 'Petrol',
#   115: 'Diesel',
#   116: 'Petrol',
#   117: 'Diesel',
#   118: 'Petrol',
#   119: 'Diesel',
#   120: 'Petrol',
#   121: 'Petrol',
#   122: 'Petrol',
#   123: 'Petrol',
#   124: 'Petrol',
#   125: 'Diesel',
#   126: 'Petrol',
#   127: 'Petrol',
#   128: 'Petrol',
#   129: 'Diesel',
#   130: 'Petrol',
#   131: 'Petrol',
#   132: 'Petrol',
#   133: 'Diesel',
#   134: 'Petrol',
#   135: 'Petrol',
#   136: 'Diesel',
#   137: 'Diesel',
#   138: 'Petrol',
#   139: 'Petrol',
#   140: 'Diesel',
#   141: 'Diesel',
#   142: 'Petrol',
#   143: 'Petrol',
#   144: 'Petrol',
#   145: 'Petrol',
#   146: 'Diesel',
#   147: 'Petrol',
#   148: 'Diesel',
#   149: 'Diesel',
#   150: 'Petrol',
#   151: 'Petrol',
#   152: 'Petrol',
#   153: 'Diesel',
#   154: 'Diesel',
#   155: 'Diesel',
#   156: 'Petrol',
#   157: 'Diesel',
#   158: 'Petrol',
#   159: 'Diesel',
#   160: 'Diesel',
#   161: 'Diesel',
#   162: 'Diesel',
#   163: 'Diesel',
#   164: 'Petrol',
#   165: 'Petrol',
#   166: 'Diesel',
#   167: 'Petrol',
#   168: 'Diesel',
#   169: 'Diesel',
#   170: 'Petrol',
#   171: 'Diesel',
#   172: 'Diesel',
#   173: 'Diesel',
#   174: 'Petrol',
#   175: 'Diesel',
#   176: 'Petrol',
#   177: 'Diesel',
#   178: 'Diesel',
#   179: 'Diesel',
#   180: 'Petrol',
#   181: 'Diesel',
#   182: 'Petrol',
#   183: 'Petrol',
#   184: 'Petrol',
#   185: 'Petrol',
#   186: 'Petrol',
#   187: 'Petrol',
#   188: 'Diesel',
#   189: 'Diesel',
#   190: 'Diesel',
#   191: 'Petrol',
#   192: 'Petrol',
#   193: 'Petrol',
#   194: 'Petrol',
#   195: 'Petrol',
#   196: 'Petrol',
#   197: 'Diesel',
#   198: 'Petrol',
#   199: 'Petrol',
#   200: 'Diesel',
#   201: 'Diesel',
#   202: 'Diesel',
#   203: 'Petrol',
#   204: 'Petrol',
#   205: 'Diesel',
#   206: 'Diesel',
#   207: 'Diesel',
#   208: 'Diesel',
#   209: 'Diesel',
#   210: 'Diesel',
#   211: 'Diesel',
#   212: 'Petrol',
#   213: 'Diesel',
#   214: 'Diesel',
#   215: 'Diesel',
#   216: 'Petrol',
#   217: 'Petrol',
#   218: 'Diesel',
#   219: 'Diesel',
#   220: 'Diesel',
#   221: 'Petrol',
#   222: 'Diesel',
#   223: 'Diesel',
#   224: 'Petrol',
#   225: 'Diesel',
#   226: 'Petrol',
#   227: 'Petrol',
#   228: 'Diesel',
#   229: 'Diesel',
#   230: 'Petrol',
#   231: 'Petrol',
#   232: 'Diesel',
#   233: 'Petrol',
#   234: 'Diesel',
#   235: 'Petrol',
#   236: 'Petrol',
#   237: 'Diesel',
#   238: 'Diesel',
#   239: 'Diesel',
#   240: 'Petrol',
#   241: 'Petrol',
#   242: 'Diesel',
#   243: 'Diesel',
#   244: 'Petrol',
#   245: 'Diesel',
#   246: 'Petrol',
#   247: 'Petrol',
#   248: 'Petrol',
#   249: 'Diesel',
#   250: 'Diesel',
#   251: 'Diesel',
#   252: 'Petrol',
#   253: 'Petrol',
#   254: 'Petrol',
#   255: 'Petrol',
#   256: 'Petrol',
#   257: 'Diesel',
#   258: 'Petrol',
#   259: 'Petrol',
#   260: 'Petrol',
#   261: 'Diesel',
#   262: 'Diesel',
#   263: 'Diesel',
#   264: 'Diesel',
#   265: 'Petrol',
#   266: 'Petrol',
#   267: 'Petrol',
#   268: 'Petrol',
#   269: 'Diesel',
#   270: 'Diesel',
#   271: 'Petrol',
#   272: 'Petrol',
#   273: 'Petrol',
#   274: 'Diesel',
#   275: 'Petrol',
#   276: 'Diesel',
#   277: 'Petrol',
#   278: 'Diesel',
#   279: 'Petrol',
#   280: 'Petrol',
#   281: 'Diesel',
#   282: 'Diesel',
#   283: 'Petrol',
#   284: 'Diesel',
#   285: 'Petrol',
#   286: 'Petrol',
#   287: 'Petrol',
#   288: 'Petrol',
#   289: 'Diesel',
#   290: 'Petrol',
#   291: 'Diesel',
#   292: 'Petrol',
#   293: 'Diesel',
#   294: 'Diesel',
#   295: 'Diesel',
#   296: 'Diesel',
#   297: 'Petrol',
#   298: 'Petrol',
#   299: 'Petrol',
#   300: 'Diesel',
#   301: 'Diesel',
#   302: 'Petrol',
#   303: 'Petrol',
#   304: 'Petrol',
#   305: 'Petrol',
#   306: 'Diesel',
#   307: 'Diesel',
#   308: 'Diesel',
#   309: 'Diesel',
#   310: 'Diesel',
#   311: 'Diesel',
#   312: 'Diesel',
#   313: 'Petrol',
#   314: 'Diesel',
#   315: 'Petrol',
#   316: 'Diesel',
#   317: 'Diesel',
#   318: 'Diesel',
#   319: 'Diesel',
#   320: 'Petrol',
#   321: 'Diesel',
#   322: 'Petrol',
#   323: 'Diesel',
#   324: 'Diesel',
#   325: 'Diesel',
#   326: 'Petrol',
#   327: 'Diesel',
#   328: 'Diesel',
#   329: 'Diesel',
#   330: 'Diesel',
#   331: 'Petrol',
#   332: 'Petrol',
#   333: 'Diesel',
#   334: 'Petrol',
#   335: 'Petrol',
#   336: 'Petrol',
#   337: 'Petrol',
#   338: 'Diesel',
#   339: 'Petrol',
#   340: 'Petrol',
#   341: 'Petrol',
#   342: 'Diesel',
#   343: 'Diesel',
#   344: 'Diesel',
#   345: 'Petrol',
#   346: 'Diesel',
#   347: 'Diesel',
#   348: 'Petrol',
#   349: 'Petrol',
#   350: 'Diesel',
#   351: 'Diesel',
#   352: 'Diesel',
#   353: 'Diesel',
#   354: 'Diesel',
#   355: 'Diesel',
#   356: 'Diesel',
#   357: 'Diesel',
#   358: 'Petrol',
#   359: 'Diesel',
#   360: 'Petrol',
#   361: 'Diesel',
#   362: 'Petrol',
#   363: 'Petrol',
#   364: 'Diesel',
#   365: 'Petrol',
#   366: 'Diesel',
#   367: 'Diesel',
#   368: 'Diesel',
#   369: 'Petrol',
#   370: 'Petrol',
#   371: 'Diesel',
#   372: 'Petrol',
#   373: 'Diesel',
#   374: 'Diesel',
#   375: 'Diesel',
#   376: 'Diesel',
#   377: 'Petrol',
#   378: 'Petrol',
#   379: 'Diesel',
#   380: 'Diesel',
#   381: 'Petrol',
#   382: 'Diesel',
#   383: 'Petrol',
#   384: 'Petrol',
#   385: 'Petrol',
#   386: 'Diesel',
#   387: 'Petrol',
#   388: 'Diesel',
#   389: 'Petrol',
#   390: 'Petrol',
#   391: 'Petrol',
#   392: 'Petrol',
#   393: 'Petrol',
#   394: 'Diesel',
#   395: 'Petrol',
#   396: 'Diesel',
#   397: 'Diesel',
#   398: 'Petrol',
#   399: 'Petrol',
#   400: 'Diesel',
#   401: 'Petrol',
#   402: 'Petrol',
#   403: 'Diesel',
#   404: 'Petrol',
#   405: 'Diesel',
#   406: 'Diesel',
#   407: 'Diesel',
#   408: 'Petrol',
#   409: 'Petrol',
#   410: 'Diesel',
#   411: 'Petrol',
#   412: 'Petrol',
#   413: 'Diesel',
#   414: 'Diesel',
#   415: 'Diesel',
#   416: 'Petrol',
#   417: 'Diesel',
#   418: 'Petrol',
#   419: 'Diesel',
#   420: 'Diesel',
#   421: 'Petrol',
#   422: 'Diesel',
#   423: 'Petrol',
#   424: 'Diesel',
#   425: 'Diesel',
#   426: 'Diesel',
#   427: 'Diesel',
#   428: 'Petrol',
#   429: 'Petrol',
#   430: 'Petrol',
#   431: 'Diesel',
#   432: 'Diesel',
#   433: 'Petrol',
#   434: 'Petrol',
#   435: 'Petrol',
#   436: 'Petrol',
#   437: 'Petrol',
#   438: 'Diesel',
#   439: 'Petrol',
#   440: 'Petrol',
#   441: 'Petrol',
#   442: 'Petrol',
#   443: 'Petrol',
#   444: 'Petrol',
#   445: 'Petrol',
#   446: 'Petrol',
#   447: 'Diesel',
#   448: 'Diesel',
#   449: 'Diesel',
#   450: 'Diesel',
#   451: 'Petrol',
#   452: 'Petrol',
#   453: 'Petrol',
#   454: 'Diesel',
#   455: 'Diesel',
#   456: 'Diesel',
#   457: 'Petrol',
#   458: 'LPG',
#   459: 'Diesel',
#   460: 'Diesel',
#   461: 'Diesel',
#   462: 'Petrol',
#   463: 'Petrol',
#   464: 'Petrol',
#   465: 'Diesel',
#   466: 'Diesel',
#   467: 'Diesel',
#   468: 'Diesel',
#   469: 'Petrol',
#   470: 'Diesel',
#   471: 'Petrol',
#   472: 'Diesel',
#   473: 'Petrol',
#   474: 'Petrol',
#   475: 'Petrol',
#   476: 'Petrol',
#   477: 'Petrol',
#   478: 'Petrol',
#   479: 'Petrol',
#   480: 'Petrol',
#   481: 'Diesel',
#   482: 'Petrol',
#   483: 'Petrol',
#   484: 'Petrol',
#   485: 'Petrol',
#   486: 'Petrol',
#   487: 'Petrol',
#   488: 'Diesel',
#   489: 'Petrol',
#   490: 'Petrol',
#   491: 'Petrol',
#   492: 'Petrol',
#   493: 'Petrol',
#   494: 'Petrol',
#   495: 'Petrol',
#   496: 'Diesel',
#   497: 'Petrol',
#   498: 'Petrol',
#   499: 'Diesel',
#   500: 'Diesel',
#   501: 'Petrol',
#   502: 'Petrol',
#   503: 'Petrol',
#   504: 'Petrol',
#   505: 'Petrol',
#   506: 'Petrol',
#   507: 'Diesel',
#   508: 'Diesel',
#   509: 'Petrol',
#   510: 'Petrol',
#   511: 'Diesel',
#   512: 'Petrol',
#   513: 'Petrol',
#   514: 'Petrol',
#   515: 'Petrol',
#   516: 'Petrol',
#   517: 'Petrol',
#   518: 'Petrol',
#   519: 'Petrol',
#   520: 'Petrol',
#   521: 'Petrol',
#   522: 'Diesel',
#   523: 'Petrol',
#   524: 'Petrol',
#   525: 'Diesel',
#   526: 'Diesel',
#   527: 'Diesel',
#   528: 'Petrol',
#   529: 'Petrol',
#   530: 'Petrol',
#   531: 'Diesel',
#   532: 'Diesel',
#   533: 'Diesel',
#   534: 'Diesel',
#   535: 'Petrol',
#   536: 'Petrol',
#   537: 'Diesel',
#   538: 'Petrol',
#   539: 'Petrol',
#   540: 'Petrol',
#   541: 'Diesel',
#   542: 'Diesel',
#   543: 'Diesel',
#   544: 'Petrol',
#   545: 'Petrol',
#   546: 'Petrol',
#   547: 'Diesel',
#   548: 'Diesel',
#   549: 'Diesel',
#   550: 'Diesel',
#   551: 'Diesel',
#   552: 'Diesel',
#   553: 'Petrol',
#   554: 'Petrol',
#   555: 'Diesel',
#   556: 'Diesel',
#   557: 'Diesel',
#   558: 'Petrol',
#   559: 'Diesel',
#   560: 'Diesel',
#   561: 'Diesel',
#   562: 'Diesel',
#   563: 'Diesel',
#   564: 'Petrol',
#   565: 'Diesel',
#   566: 'Petrol',
#   567: 'Petrol',
#   568: 'Diesel',
#   569: 'Petrol',
#   570: 'Petrol',
#   571: 'Diesel',
#   572: 'Petrol',
#   573: 'Petrol',
#   574: 'Petrol',
#   575: 'Petrol',
#   576: 'Diesel',
#   577: 'Diesel',
#   578: 'Petrol',
#   579: 'Diesel',
#   580: 'Petrol',
#   581: 'Diesel',
#   582: 'Petrol',
#   583: 'Diesel',
#   584: 'LPG',
#   585: 'Diesel',
#   586: 'Diesel',
#   587: 'Diesel',
#   588: 'Diesel',
#   589: 'Diesel',
#   590: 'Petrol',
#   591: 'Petrol',
#   592: 'Diesel',
#   593: 'Petrol',
#   594: 'Petrol',
#   595: 'Petrol',
#   596: 'Diesel',
#   597: 'Petrol',
#   598: 'Diesel',
#   599: 'Petrol',
#   600: 'Diesel',
#   601: 'Diesel',
#   602: 'Diesel',
#   603: 'Diesel',
#   604: 'Diesel',
#   605: 'Petrol',
#   606: 'Diesel',
#   607: 'Diesel',
#   608: 'Diesel',
#   609: 'Diesel',
#   610: 'Petrol',
#   611: 'Petrol',
#   612: 'Petrol',
#   613: 'Petrol',
#   614: 'Petrol',
#   615: 'Petrol',
#   616: 'Diesel',
#   617: 'Petrol',
#   618: 'Petrol',
#   619: 'Petrol',
#   620: 'Diesel',
#   621: 'Petrol',
#   622: 'Petrol',
#   623: 'Diesel',
#   624: 'Diesel',
#   625: 'Diesel',
#   626: 'Diesel',
#   627: 'Diesel',
#   628: 'Petrol',
#   629: 'Diesel',
#   630: 'Diesel',
#   631: 'Diesel',
#   632: 'Petrol',
#   633: 'Diesel',
#   634: 'Petrol',
#   635: 'Petrol',
#   636: 'Diesel',
#   637: 'Diesel',
#   638: 'Diesel',
#   639: 'Diesel',
#   640: 'Diesel',
#   641: 'Diesel',
#   642: 'Petrol',
#   643: 'Diesel',
#   644: 'Petrol',
#   645: 'Diesel',
#   646: 'Diesel',
#   647: 'Diesel',
#   648: 'Diesel',
#   649: 'Diesel',
#   650: 'Diesel',
#   651: 'Petrol',
#   652: 'Diesel',
#   653: 'Petrol',
#   654: 'Diesel',
#   655: 'Petrol',
#   656: 'Diesel',
#   657: 'Diesel',
#   658: 'Diesel',
#   659: 'Diesel',
#   660: 'Petrol',
#   661: 'Petrol',
#   662: 'Petrol',
#   663: 'Petrol',
#   664: 'Diesel',
#   665: 'Petrol',
#   666: 'Petrol',
#   667: 'Petrol',
#   668: 'Petrol',
#   669: 'Petrol',
#   670: 'Petrol',
#   671: 'Diesel',
#   672: 'Diesel',
#   673: 'Diesel',
#   674: 'Petrol',
#   675: 'Petrol',
#   676: 'Diesel',
#   677: 'Petrol',
#   678: 'Petrol',
#   679: 'Petrol',
#   680: 'Diesel',
#   681: 'Petrol',
#   682: 'Diesel',
#   683: 'Diesel',
#   684: 'Diesel',
#   685: 'Petrol',
#   686: 'Diesel',
#   687: 'Diesel',
#   688: 'Diesel',
#   689: 'Diesel',
#   690: 'Petrol',
#   691: 'Petrol',
#   692: 'Diesel',
#   693: 'Petrol',
#   694: 'Petrol',
#   695: 'Petrol',
#   696: 'Diesel',
#   697: 'Petrol',
#   698: 'Diesel',
#   699: 'Petrol',
#   700: 'Petrol',
#   701: 'Petrol',
#   702: 'Petrol',
#   703: 'Diesel',
#   704: 'Petrol',
#   705: 'Petrol',
#   706: 'Petrol',
#   707: 'Diesel',
#   708: 'Diesel',
#   709: 'Petrol',
#   710: 'Petrol',
#   711: 'Petrol',
#   712: 'Diesel',
#   713: 'Diesel',
#   714: 'Diesel',
#   715: 'Petrol',
#   716: 'Petrol',
#   717: 'Petrol',
#   718: 'Diesel',
#   719: 'Diesel',
#   720: 'Petrol',
#   721: 'Diesel',
#   722: 'Petrol',
#   723: 'Petrol',
#   724: 'Petrol',
#   725: 'Petrol',
#   726: 'Petrol',
#   727: 'Diesel',
#   728: 'Diesel',
#   729: 'Petrol',
#   730: 'Diesel',
#   731: 'Petrol',
#   732: 'Petrol',
#   733: 'Petrol',
#   734: 'Petrol',
#   735: 'Diesel',
#   736: 'Diesel',
#   737: 'Petrol',
#   738: 'Petrol',
#   739: 'Petrol',
#   740: 'Diesel',
#   741: 'Diesel',
#   742: 'Diesel',
#   743: 'Diesel',
#   744: 'Diesel',
#   745: 'Petrol',
#   746: 'Petrol',
#   747: 'Petrol',
#   748: 'Petrol',
#   749: 'Petrol',
#   750: 'Diesel',
#   751: 'Diesel',
#   752: 'Petrol',
#   753: 'Petrol',
#   754: 'Petrol',
#   755: 'Petrol',
#   756: 'Diesel',
#   757: 'Petrol',
#   758: 'Petrol',
#   759: 'Petrol',
#   760: 'Diesel',
#   761: 'Diesel',
#   762: 'Diesel',
#   763: 'Diesel',
#   764: 'Diesel',
#   765: 'Petrol',
#   766: 'Petrol',
#   767: 'Petrol',
#   768: 'Petrol',
#   769: 'Petrol',
#   770: 'Diesel',
#   771: 'Diesel',
#   772: 'Petrol',
#   773: 'Petrol',
#   774: 'Diesel',
#   775: 'Petrol',
#   776: 'Diesel',
#   777: 'Petrol',
#   778: 'Petrol',
#   779: 'Petrol',
#   780: 'Diesel',
#   781: 'Petrol',
#   782: 'Diesel',
#   783: 'Petrol',
#   784: 'Petrol',
#   785: 'Petrol',
#   786: 'Petrol',
#   787: 'Diesel',
#   788: 'Petrol',
#   789: 'Petrol',
#   790: 'Diesel',
#   791: 'Petrol',
#   792: 'Diesel',
#   793: 'Petrol',
#   794: 'Diesel',
#   795: 'Diesel',
#   796: 'Diesel',
#   797: 'Diesel',
#   798: 'Petrol',
#   799: 'Petrol',
#   800: 'Diesel',
#   801: 'Diesel',
#   802: 'Petrol',
#   803: 'Petrol',
#   804: 'Diesel',
#   805: 'Petrol',
#   806: 'Petrol',
#   807: 'Petrol',
#   808: 'Diesel',
#   809: 'Petrol',
#   810: 'Petrol',
#   811: 'Diesel',
#   812: 'Petrol',
#   813: 'Diesel',
#   814: 'Diesel'}}

# %%
pickle.dump(car.to_dict(),open('car_dict.pkl','wb'))

# %%
car['year'].unique().sort
# Out:
# <function ndarray.sort>
